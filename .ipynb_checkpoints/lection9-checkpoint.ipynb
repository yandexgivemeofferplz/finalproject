# %%
import numpy as np
import pandas as pd
import xml.etree.ElementTree as et
import pymorphy2
import re

# %%
def getdata(filename):
    parsedXML = et.parse(filename)
    dfcols = ['id', 'type', 'text', 'url', 'mood']
    data = pd.DataFrame(columns=dfcols)
    for node in parsedXML.getroot():
        #print (node.tag, node.attrib)
        sentence_id = node.attrib['id']
        speech_type = eval = url = text = None
        text = node[0].text.strip()
        eval = node[1].text.strip()
        url = node[2].text.strip()
        speech_type = node[0].attrib.get('type')
        #print(speech_type)

        data = data.append(
            pd.Series([sentence_id, speech_type, text, url, eval], index = dfcols), ignore_index = True
        )
    data['id'] = pd.to_numeric(data['id'])
    data.index = data['id']
    data = data.drop(['id'], axis=1)

    #убираем амбивалентные новости
    data = data.loc[(data['mood'] == '0') | (data['mood'] == '+') | (data['mood'] == '-')]

    #сохраняем url
    data.loc[:,'url'] = data.loc[:,'url'].str.replace('http://', '')
    data.loc[:,'url'] = data.loc[:,'url'].str.replace('^www.', '')
    data.loc[:,'url'] = data.loc[:,'url'].str.split('/').str.get(0)


    #сохраняем страну, в которой была опубликована новость
    data['country'] = data['url'].str.split('.').str.get(-1)

    #делаем доп. столбцы, соотв. странам
    data['RU'] = 0
    data['UA'] = 0
    data['COM'] = 0
    data['ANOTHER'] = 0

    data.loc[data['country'] == 'ru', 'RU'] = 1
    data.loc[data['country'] == 'ua', 'UA'] = 1
    data.loc[data['country'] == 'com', 'COM'] = 1
    data.loc[(data['country'] != 'ru') & (data['country'] != 'ua') & (data['country'] != 'com') , 'ANOTHER'] = 1

    #1 - прямая речь, 0 - обычная
    data['type'] = data['type'].str.replace('indirect', '0')
    data['type'] = data['type'].str.replace('direct', '1')
    data['type'] = pd.to_numeric(data['type'])

    #хочется, чтобы настроение новости было выражено числом (+ = 1, 0 = 0, - = -1)
    data['mood'] = data['mood'].str.replace('+', '1')
    data['mood'] = data['mood'].str.replace('-', '-1')
    data['mood'] = pd.to_numeric(data['mood'])
    data

    #убираем столбцы, кот. больше не используем
    data = data.drop(['url', 'country'], axis=1)
    return data

data_train = getdata("train/news_eval_train.xml")
data_test = getdata('test/news_eval_test.xml')
data_test
# Out:
#       type                                               text  mood  RU  UA  \
# id
# 1001     1  "Джазбэнд под руководством\nПеппе Сервилло, ко...     0   1   0
# 1003     1  "Посредством этих структур\nдесяткам тысяч изб...    -1   0   0
# 1004     1  "Появилось очень много бедных\nизбирателей. В ...    -1   0   0
# 1005     1  "За теленовостями - главным\nисточником информ...    -1   0   0
# 1006     1  "Такого раньше никогда не было,\nчтобы местные...    -1   0   0
# 1007     1  "Он рассказал, что\nграбители воспользовались ...    -1   1   0
# 1008     1  "Экспедиция уже завершилась.\nОна прошла в пол...     0   1   0
# 1009     1  "Следственным комитетом РФ\nпостановление след...    -1   1   0
# 1010     1  "Преступление, по словам\nБалгабаева, произошл...    -1   1   0
# 1011     1  "Нужно учитывать не только\nрезультаты экзамен...     0   1   0
# 1013     1  "Ваши достижения, конечно,\nдолжны быть вознаг...     1   1   0
# 1014     1  "Свой победный заплыв Олеся\nВладыкина закончи...     1   1   0
# 1017     1  "Нам необходимы безопасность и\nстабильность в...     1   0   0
# 1018     1  "Хулучи Кылыч останется в памяти\nазербайджанс...     1   0   0
# 1020     1  "Нужно увеличивать нагрузку. Если\nна Пекинско...     0   1   0
# 1022     1  "Введение налога может привести к\nмассовому у...    -1   1   0
# 1023     1  "Под разговоры о свободе на карте\nмира станов...    -1   1   0
# 1024     1  "Мы работаем на сегодняшний\nдень и с населени...     0   1   0
# 1026     1  "С девяти утра четверга до\nнастоящего времени...    -1   0   0
# 1027     1  "В 09.05 в Анапском районе в\nрезультате порыв...    -1   1   0
# 1028     1  "Я - за то, чтобы\nУкраина вошла в ЕС. Я хочу ...     0   0   1
# 1030     1  "На этот год у нас запланирован\nввод 222 квар...     0   1   0
# 1031     1  "Мой последний роман можно\nназвать лучшим, чт...     1   1   0
# 1032     1  "Студентка 2 курса\nМосковского института элек...    -1   1   0
# 1033     1  "На корабле "Союз ТМА-06М"\nпринято решение за...     0   1   0
# 1034     1  "Миллионы людей знают Вас как\nталантливого ди...     1   1   0
# 1036     1  "Следственно-оперативная группа\nпредварительн...    -1   1   0
# 1037     1  "Единственный человек, по\nвине которого экс-п...    -1   1   0
# 1041     1  "Предполагается, что через\nофициальный электр...     0   1   0
# 1042     1  "Почта России" гарантирует, что\nтолько вы смо...     1   1   0
# ...    ...                                                ...   ...  ..  ..
# 7959     1  "На сегодняшний день мы по всем\nкрупным видам...     1   1   0
# 7960     1  "Будет наш танк, немецкого\nне будет. Более то...     0   1   0
# 7961     1  "До конца года будет 150 машин, в\nследующем г...     1   1   0
# 7962     1  "Мы надеемся, что все планы,\nкоторые поставил...     1   1   0
# 7963     1  "Сегодня днем столкнулись четыре\nавтомобиля, ...    -1   1   0
# 7964     1  "Столкнулись четыре машины, при\nэтом одна из ...    -1   1   0
# 7965     1  "Очевидно, что\nМайами будет на первой строчке...     1   0   1
# 7966     1  "Если бы я думал\nо деньгах, которые приходитс...    -1   1   0
# 7967     1  "Мы стабильно занимаемся шесть\nдней в неделю,...     0   1   0
# 7968     1  "Буквально несколько часов назад\nсамолет Л-39...    -1   0   1
# 7969     1  "Этот уровень использования iOS 6\nговорит о з...     1   1   0
# 7970     1  "Страны, которые находятся в\nтранзитном состо...     0   0   0
# 7971     1  "Поэтому Майдана у нас\nне будет, и я надеюсь,...     1   0   0
# 7973     1  "Мы же видим, с какими\nпроблемами сейчас стал...    -1   0   1
# 7974     1  "Особо подчеркну, что эта\nпроцедура касается ...    -1   0   1
# 7975     1  "Ножевое ранение\n19-летний учащийся колледжа ...    -1   0   0
# 7976     1  "Я считаю, что\nразделение Косово является еди...     0   0   1
# 7977     1  "Некоторые возражают,\nзаявляя, что это вызове...    -1   0   1
# 7979     1  "Очень\nпереживала за Дашу Домрачеву в той бор...     1   1   0
# 7980     1  "Мазерати" доказала\nпобедой в прошлом году с ...     1   1   0
# 7981     1  "Отношение руководителя\nрегиона к развитию фи...     1   1   0
# 7983     1  "Вы - граждане России". Направляю\nих на честн...     1   1   0
# 7984     1  "Нам надо продолжать подчищать\nнастройки, пот...     0   1   0
# 7985     1  "Если меня не\nбеспокоит травма, то я могу мно...     1   1   0
# 7986     1  "Участников мало,\nпотому что руководство Межд...    -1   1   0
# 7988     1  "Правительство и Министерство\nспорта Российск...     1   1   0
# 7992     1  "Я сейчас\nнахожусь в некой эйфории, потому чт...     1   1   0
# 7997     1  "Кроме моего напарника\nЛьюиса Хэмилтона, Себа...     1   1   0
# 7998     1  "Вы никогда не знаете,\nчто случится. В Формул...     0   1   0
# 8000     1  "Авиабилет журналисту\nпоменяли, он может улет...    -1   0   0
#
#       COM  ANOTHER
# id
# 1001    0        0
# 1003    0        1
# 1004    0        1
# 1005    0        1
# 1006    0        1
# 1007    0        0
# 1008    0        0
# 1009    0        0
# 1010    0        0
# 1011    0        0
# 1013    0        0
# 1014    0        0
# 1017    0        1
# 1018    0        1
# 1020    0        0
# 1022    0        0
# 1023    0        0
# 1024    0        0
# 1026    0        1
# 1027    0        0
# 1028    0        0
# 1030    0        0
# 1031    0        0
# 1032    0        0
# 1033    0        0
# 1034    0        0
# 1036    0        0
# 1037    0        0
# 1041    0        0
# 1042    0        0
# ...   ...      ...
# 7959    0        0
# 7960    0        0
# 7961    0        0
# 7962    0        0
# 7963    0        0
# 7964    0        0
# 7965    0        0
# 7966    0        0
# 7967    0        0
# 7968    0        0
# 7969    0        0
# 7970    1        0
# 7971    1        0
# 7973    0        0
# 7974    0        0
# 7975    0        1
# 7976    0        0
# 7977    0        0
# 7979    0        0
# 7980    0        0
# 7981    0        0
# 7983    0        0
# 7984    0        0
# 7985    0        0
# 7986    0        0
# 7988    0        0
# 7992    0        0
# 7997    0        0
# 7998    0        0
# 8000    0        1
#
# [4573 rows x 7 columns]

# %%
morph = pymorphy2.MorphAnalyzer()

# %%
def strtonormalform(line, should_delete = {'PREP', 'CONJ', 'PRCL', 'INTJ'}):
    ans = ''
    words = re.findall(r"[\w]+[\w|-]*", line)
    for word in words:
        lexInfo = morph.parse(word)[0]
        lex = lexInfo.normal_form
        if (lexInfo.tag.POS not in should_delete) and (re.match(r"[-+]?\d+$", lex) is None) :#союзы, предлоги и т.п. не сохраняем
            ans = ans + ' ' + lex
    return ans

data_train['text'] = data_train['text'].apply(strtonormalform)
data_test['text'] = data_test['text'].apply(strtonormalform)
data_train.to_pickle('data_train')
data_test.to_pickle('data_test')

# %% [markdown]
# # Если не хотим из раза пересчитывать тестовые данные - грузим их из pickle-файла

# %%
data_train = pd.read_pickle('data_train')
data_test = pd.read_pickle('data_test')
morph = pymorphy2.MorphAnalyzer()

#смотрим топ-25 слов
allwords = {}
i=0
for line in data_train['text']:
    #print(line)
    i+=1
    words = re.findall(r"[\w]+[\w|-]*", line)
    for w in words:
        lexInfo = morph.parse(w)[0]
        lex = lexInfo.normal_form
        allwords[w] = allwords.get(w, 0) + 1
wordnum = {}
i = 1
for w in sorted(allwords.items(), key = lambda x: -x[1]):
    wordnum[w[0]] = i
    i+=1

# %%
#print top 25 words
i=0
for w in sorted(allwords.items(), key = lambda x: -x[1]):
    print(w[0], w[1])
    i+=1
    if i==25: break

# %%
#если удаляем местоимения и числительные
SHOULD_I_DELETE_MORE = False

if SHOULD_I_DELETE_MORE:
    data_train['text'] = data_train['text'].apply(strtonormalform, should_delete ={'NUMR', 'NPRO'})
    data_test['text'] = data_test['text'].apply(strtonormalform, should_delete ={'NUMR', 'NPRO'})

# %%
from sklearn.metrics import fbeta_score
from sklearn.metrics import accuracy_score
def trainTestClf(clf, X_train, y_train, X_test):
    clf.fit(X_train, y_train)
    return clf.predict(X_test)

def printF2(y_test, y_pred, vType ='tf-idf', cType='Bayess'):
    print("Vectorizing: ", vType, ". Classifier: ", cType, sep='')
    print('F2 micro score = %0.3f' % fbeta_score(y_test, y_pred, beta=2, average = 'micro'))
    print('F2 macro = %0.3f' % fbeta_score(y_test, y_pred, beta=2, average = 'macro'))
    print("Accuracy = %0.3f" % accuracy_score(y_test, y_pred))

# %%
#бинарная вектаризация
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(binary = True)
X_train = vectorizer.fit_transform(data_train.loc[:,'text'])
X_test = vectorizer.transform(data_test.loc[:,'text'])
y_train, y_test = data_train['mood'], data_test['mood']
X_train, X_test
# Out:
# (<3893x14204 sparse matrix of type '<class 'numpy.int64'>'
#  	with 89815 stored elements in Compressed Sparse Row format>,
#  <4573x14204 sparse matrix of type '<class 'numpy.int64'>'
#  	with 103238 stored elements in Compressed Sparse Row format>)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import fbeta_score

clf = MultinomialNB(alpha=0.1)
printF2(y_test, trainTestClf(clf, X_train, y_train, X_test), vType = "Boolean", cType = 'Naieve Bayess, alpha = 1')
# Out:
# Vectorizing: Boolean. Classifier: Naieve Bayess, alpha = 1
# F2 micro score = 0.611
# F2 macro = 0.587
# Accuracy = 0.611

# %%
from sklearn import svm

clf = svm.LinearSVC()
printF2(y_test, trainTestClf(clf, X_train, y_train, X_test), vType = "Boolean", cType = 'svm')
# Out:
# Vectorizing: Boolean. Classifier: svm
# F2 micro score = 0.581
# F2 macro = 0.562
# Accuracy = 0.581

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators = 100, random_state = 0)
printF2(y_test, trainTestClf(clf, X_train, y_train, X_test), vType = "Boolean", cType = 'RF')
# Out:
# Vectorizing: Boolean. Classifier: RF
# F2 micro score = 0.553
# F2 macro = 0.481
# Accuracy = 0.553

# %%
#частоты
vectorizer = CountVectorizer()
X_train = vectorizer.fit_transform(data_train.loc[:,'text'])
X_test = vectorizer.transform(data_test.loc[:,'text'])
y_train, y_test = data_train['mood'], data_test['mood']
X_train, X_test
# Out:
# (<3893x14204 sparse matrix of type '<class 'numpy.int64'>'
#  	with 89815 stored elements in Compressed Sparse Row format>,
#  <4573x14204 sparse matrix of type '<class 'numpy.int64'>'
#  	with 103238 stored elements in Compressed Sparse Row format>)

# %%
from sklearn.naive_bayes import MultinomialNB

clf = MultinomialNB(alpha=0.3)
printF2(y_test, trainTestClf(clf, X_train, y_train, X_test), vType = "Frequency", cType = 'Naieve Bayess, alpha = 0.1')
# Out:
# Vectorizing: Frequency. Classifier: Naieve Bayess, alpha = 0.1
# F2 micro score = 0.618
# F2 macro = 0.593
# Accuracy = 0.618

# %%
from sklearn import svm

clf = svm.LinearSVC()
printF2(y_test, trainTestClf(clf, X_train, y_train, X_test), vType = "Frequency", cType = 'svm')
# Out:
# Vectorizing: Frequency. Classifier: svm
# F2 micro score = 0.574
# F2 macro = 0.554
# Accuracy = 0.574

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators = 100, random_state = 0)
printF2(y_test, trainTestClf(clf, X_train, y_train, X_test), vType = "Frequency", cType = 'RF')
# Out:
# Vectorizing: Frequency. Classifier: RF
# F2 micro score = 0.559
# F2 macro = 0.486
# Accuracy = 0.559

# %%
#tf-idf
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(data_train.loc[:,'text'])
X_test = vectorizer.transform(data_test.loc[:,'text'])
y_train, y_test = data_train['mood'], data_test['mood']
X_train, X_test
# Out:
# (<3893x14204 sparse matrix of type '<class 'numpy.float64'>'
#  	with 89815 stored elements in Compressed Sparse Row format>,
#  <4573x14204 sparse matrix of type '<class 'numpy.float64'>'
#  	with 103238 stored elements in Compressed Sparse Row format>)

# %%
from sklearn.naive_bayes import MultinomialNB

clf = MultinomialNB(alpha=0.06)
printF2(y_test, trainTestClf(clf, X_train, y_train, X_test), cType = 'Naieve Bayess, alpha = 1')
# Out:
# Vectorizing: tf-idf. Classifier: Naieve Bayess, alpha = 1
# F2 micro score = 0.609
# F2 macro = 0.570
# Accuracy = 0.609

# %%
from sklearn import svm

clf = svm.LinearSVC()
printF2(y_test, trainTestClf(clf, X_train, y_train, X_test), cType = 'svm')
# Out:
# Vectorizing: tf-idf. Classifier: svm
# F2 micro score = 0.601
# F2 macro = 0.568
# Accuracy = 0.601

# %%
clf = RandomForestClassifier(n_estimators = 100, random_state = 0)
printF2(y_test, trainTestClf(clf, X_train, y_train, X_test), cType = 'RF')
# Out:
# Vectorizing: tf-idf. Classifier: RF
# F2 micro score = 0.552
# F2 macro = 0.482
# Accuracy = 0.552

# %%
clf = RandomForestClassifier(n_estimators = 100, random_state = 0)
printF2(data_test['mood'], trainTestClf(clf, data_train.loc[:,['type', 'RU', 'UA', 'COM', 'ANOTHER']], data_train['mood'], data_test.loc[:,['type', 'RU', 'UA', 'COM', 'ANOTHER']]), cType = 'RF')
# Out:
# Vectorizing: tf-idf. Classifier: RF
# F2 micro score = 0.260
# F2 macro score = 0.413
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
rf = RandomForestClassifier(n_estimators = 100, random_state = 0)
mnb = MultinomialNB(alpha=0.1)
svc = svm.LinearSVC()
vote = VotingClassifier(estimators = [('mnb', mnb), ('rf', rf), ('svm', svc)])
printF2(y_test, trainTestClf(vote, X_train, y_train, X_test), cType = 'voting KNN, MNB, RF')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-9fafac8a6079> in <module>()
#       2 mnb = MultinomialNB(alpha=0.1)
#       3 svc = svm.LinearSVC()
# ----> 4 vote = VotingClassifier(estimators = [('mnb', mnb), ('rf', rf), ('svm', svc)])
#       5 printF2(y_test, trainTestClf(vote, X_train, y_train, X_test), cType = 'voting KNN, MNB, RF')
#
# NameError: name 'VotingClassifier' is not defined

# %% [markdown]
# # Далее обучаем нейросетку

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing.text import Tokenizer
data_train = pd.read_pickle('data_train')
data_test = pd.read_pickle('data_test')
y_train, y_test = data_train['mood'], data_test['mood']
i=0
for line in data_train['text']:
    #print(line)
    i+=1
    words = re.findall(r"[\w]+[\w|-]*", line)
    for w in words:
        lexInfo = morph.parse(w)[0]
        lex = lexInfo.normal_form
        allwords[w] = allwords.get(w, 0) + 1
wordnum = {}
i = 1
for w in sorted(allwords.items(), key = lambda x: -x[1]):
    wordnum[w[0]] = i
    i+=1

# %%
#нумеруем все слова
avg_len = 0
NUMCUT = 25 #режем после 25 слова
i=1


X_train = []
X_test = []
for line in data_train['text']:
    tmp = []
    words = re.findall(r"[\w]+[\w|-]*", line)
    avg_len += len(words)
    j = 0
    while j<NUMCUT:
        for w in words:
            if w in wordnum:
                j+=1
                tmp.append(wordnum[w])
            if j == NUMCUT:
                break
    X_train.append(tmp)
    
for line in data_test['text']:
    tmp = []
    words = re.findall(r"[\w]+[\w|-]*", line)
    j = 0
    if (len(words)>0):
        while j<NUMCUT:
            for w in words:
                if w in wordnum:
                    tmp.append(wordnum[w])
                    j+=1
                if j == NUMCUT:
                    break
    else:
        for j in range(25):
            tmp.append(1)
    X_test.append(tmp)
X_test
# Out:
# [[215,
#   5,
#   14,
#   22,
#   636,
#   2038,
#   6070,
#   378,
#   2,
#   10120,
#   69,
#   393,
#   72,
#   2429,
#   3380,
#   4648,
#   207,
#   60,
#   13027,
#   593,
#   215,
#   5,
#   14,
#   22,
#   636],
#  [13,
#   547,
#   920,
#   66,
#   588,
#   710,
#   192,
#   1274,
#   44,
#   2510,
#   1761,
#   178,
#   7,
#   13,
#   547,
#   920,
#   66,
#   588,
#   710,
#   192,
#   1274,
#   44,
#   2510,
#   1761,
#   178],
#  [681,
#   58,
#   249,
#   8094,
#   588,
#   1890,
#   10743,
#   718,
#   588,
#   353,
#   214,
#   205,
#   2071,
#   1375,
#   1357,
#   1090,
#   4,
#   62,
#   673,
#   756,
#   681,
#   58,
#   249,
#   8094,
#   588],
#  [71,
#   210,
#   235,
#   3630,
#   1313,
#   4524,
#   402,
#   7,
#   375,
#   160,
#   158,
#   1842,
#   71,
#   210,
#   235,
#   3630,
#   1313,
#   4524,
#   402,
#   7,
#   375,
#   160,
#   158,
#   1842,
#   71],
#  [20,
#   424,
#   850,
#   1,
#   313,
#   343,
#   2069,
#   2828,
#   19,
#   161,
#   140,
#   199,
#   1485,
#   3,
#   7868,
#   957,
#   47,
#   56,
#   30,
#   20,
#   424,
#   850,
#   1,
#   313,
#   343],
#  [2,
#   60,
#   4564,
#   2204,
#   1658,
#   2,
#   216,
#   1455,
#   3768,
#   367,
#   2501,
#   66,
#   67,
#   7,
#   101,
#   41,
#   2,
#   60,
#   4564,
#   2204,
#   1658,
#   2,
#   216,
#   1455,
#   3768],
#  [3759,
#   26,
#   4953,
#   17,
#   252,
#   350,
#   582,
#   2149,
#   133,
#   28,
#   543,
#   3240,
#   1487,
#   1192,
#   6667,
#   287,
#   3759,
#   3147,
#   1101,
#   5937,
#   1272,
#   9066,
#   3738,
#   2750,
#   558],
#  [285,
#   120,
#   81,
#   584,
#   285,
#   118,
#   1345,
#   81,
#   6012,
#   986,
#   154,
#   32,
#   90,
#   37,
#   70,
#   660,
#   1250,
#   1361,
#   6,
#   1339,
#   1950,
#   6,
#   154,
#   32,
#   655],
#  [183,
#   102,
#   191,
#   99,
#   148,
#   2,
#   571,
#   1747,
#   30,
#   210,
#   735,
#   167,
#   183,
#   102,
#   191,
#   99,
#   148,
#   2,
#   571,
#   1747,
#   30,
#   210,
#   735,
#   167,
#   183],
#  [156,
#   835,
#   92,
#   10207,
#   2221,
#   1140,
#   226,
#   22,
#   92,
#   3336,
#   51,
#   1144,
#   739,
#   25,
#   5597,
#   1205,
#   1686,
#   641,
#   158,
#   370,
#   358,
#   125,
#   802,
#   73,
#   101],
#  [948,
#   1205,
#   25,
#   1,
#   2602,
#   739,
#   2426,
#   89,
#   88,
#   153,
#   68,
#   53,
#   2677,
#   140,
#   1954,
#   2607,
#   428,
#   83,
#   67,
#   11356,
#   83,
#   67,
#   11121,
#   83,
#   67],
#  [14,
#   10962,
#   2192,
#   365,
#   3174,
#   93,
#   1135,
#   8414,
#   2,
#   21,
#   465,
#   40,
#   1257,
#   356,
#   131,
#   188,
#   3174,
#   140,
#   685,
#   13,
#   116,
#   72,
#   144,
#   92,
#   11],
#  [3,
#   86,
#   198,
#   1520,
#   18,
#   24,
#   251,
#   1025,
#   3,
#   86,
#   198,
#   1520,
#   18,
#   24,
#   251,
#   1025,
#   3,
#   86,
#   198,
#   1520,
#   18,
#   24,
#   251,
#   1025,
#   3],
#  [336,
#   1416,
#   1996,
#   179,
#   21,
#   132,
#   5724,
#   1025,
#   942,
#   1743,
#   334,
#   336,
#   1416,
#   1996,
#   179,
#   21,
#   132,
#   5724,
#   1025,
#   942,
#   1743,
#   334,
#   336,
#   1416,
#   1996],
#  [156,
#   2141,
#   2979,
#   8047,
#   1257,
#   18,
#   3006,
#   40,
#   2327,
#   5,
#   1593,
#   3202,
#   13,
#   116,
#   1593,
#   3202,
#   86,
#   5239,
#   4566,
#   7051,
#   4983,
#   21,
#   236,
#   156,
#   2141],
#  [1772,
#   421,
#   16,
#   436,
#   767,
#   2754,
#   1629,
#   77,
#   238,
#   1117,
#   272,
#   383,
#   226,
#   271,
#   1566,
#   421,
#   376,
#   102,
#   1772,
#   421,
#   16,
#   436,
#   767,
#   2754,
#   1629],
#  [1494,
#   404,
#   1215,
#   207,
#   1264,
#   11,
#   552,
#   4494,
#   146,
#   29,
#   213,
#   1494,
#   404,
#   1215,
#   207,
#   1264,
#   11,
#   552,
#   4494,
#   146,
#   29,
#   213,
#   1494,
#   404,
#   1215],
#  [3,
#   76,
#   679,
#   45,
#   310,
#   1290,
#   1063,
#   405,
#   379,
#   1565,
#   1486,
#   508,
#   11,
#   1119,
#   33,
#   1565,
#   1486,
#   52,
#   703,
#   4,
#   17,
#   3,
#   76,
#   679,
#   45],
#  [1365,
#   1561,
#   880,
#   659,
#   22,
#   1523,
#   1527,
#   2771,
#   203,
#   63,
#   19,
#   1096,
#   12,
#   614,
#   924,
#   830,
#   395,
#   786,
#   463,
#   175,
#   713,
#   61,
#   7,
#   1365,
#   1561],
#  [78,
#   92,
#   4002,
#   1903,
#   191,
#   176,
#   4403,
#   131,
#   972,
#   354,
#   310,
#   66,
#   19,
#   827,
#   8133,
#   28,
#   29,
#   12439,
#   78,
#   92,
#   4002,
#   1903,
#   191,
#   176,
#   4403],
#  [8,
#   49,
#   2004,
#   759,
#   8,
#   85,
#   85,
#   140,
#   21,
#   9452,
#   1606,
#   12691,
#   188,
#   1283,
#   219,
#   2853,
#   1,
#   275,
#   241,
#   324,
#   213,
#   8,
#   49,
#   2004,
#   759],
#  [13,
#   6,
#   3,
#   1120,
#   3109,
#   509,
#   428,
#   695,
#   174,
#   362,
#   13550,
#   600,
#   2507,
#   66,
#   1223,
#   246,
#   7,
#   673,
#   880,
#   13,
#   6,
#   3,
#   1120,
#   3109,
#   509],
#  [134,
#   135,
#   1060,
#   108,
#   1045,
#   77,
#   8,
#   98,
#   241,
#   1748,
#   115,
#   1978,
#   341,
#   7,
#   10135,
#   134,
#   135,
#   1060,
#   108,
#   1045,
#   77,
#   8,
#   98,
#   241,
#   1748],
#  [13481,
#   857,
#   377,
#   544,
#   1925,
#   624,
#   4,
#   148,
#   3050,
#   78,
#   2127,
#   391,
#   13246,
#   5569,
#   10,
#   7173,
#   2653,
#   10649,
#   17,
#   294,
#   965,
#   166,
#   408,
#   83,
#   67],
#  [2384,
#   1283,
#   68,
#   53,
#   3362,
#   6387,
#   123,
#   435,
#   1471,
#   2384,
#   111,
#   688,
#   3193,
#   131,
#   12861,
#   2484,
#   7,
#   229,
#   2384,
#   1283,
#   68,
#   53,
#   3362,
#   6387,
#   123],
#  [83,
#   19,
#   151,
#   140,
#   2907,
#   8943,
#   1899,
#   6,
#   76,
#   1513,
#   1725,
#   140,
#   826,
#   4939,
#   4253,
#   1070,
#   3053,
#   5,
#   620,
#   15,
#   1689,
#   4819,
#   181,
#   18,
#   24],
#  [7076,
#   143,
#   2832,
#   356,
#   11385,
#   218,
#   216,
#   5747,
#   1035,
#   1412,
#   1566,
#   118,
#   5992,
#   97,
#   5,
#   226,
#   1535,
#   87,
#   294,
#   29,
#   35,
#   7076,
#   143,
#   2832,
#   356],
#  [849,
#   19,
#   730,
#   5,
#   3378,
#   87,
#   3778,
#   17,
#   626,
#   5,
#   3579,
#   694,
#   103,
#   969,
#   14,
#   703,
#   498,
#   1008,
#   211,
#   7,
#   727,
#   849,
#   19,
#   730,
#   5],
#  [3435,
#   324,
#   1925,
#   2459,
#   2266,
#   180,
#   2120,
#   965,
#   2463,
#   1116,
#   303,
#   1116,
#   303,
#   108,
#   1,
#   914,
#   162,
#   1184,
#   6692,
#   914,
#   162,
#   205,
#   318,
#   3435,
#   324],
#  [6293,
#   23,
#   2379,
#   140,
#   180,
#   63,
#   3137,
#   1925,
#   1258,
#   2459,
#   2236,
#   6724,
#   6293,
#   23,
#   180,
#   2379,
#   694,
#   6610,
#   1463,
#   3137,
#   2459,
#   19,
#   5,
#   85,
#   1],
#  [12,
#   676,
#   181,
#   12,
#   376,
#   41,
#   102,
#   47,
#   56,
#   4704,
#   7123,
#   4704,
#   12,
#   676,
#   181,
#   12,
#   376,
#   41,
#   102,
#   47,
#   56,
#   4704,
#   7123,
#   4704,
#   12],
#  [7985,
#   3068,
#   2032,
#   183,
#   42,
#   5010,
#   1781,
#   104,
#   4980,
#   2586,
#   29,
#   35,
#   7985,
#   3068,
#   2032,
#   183,
#   42,
#   5010,
#   1781,
#   104,
#   4980,
#   2586,
#   29,
#   35,
#   7985],
#  [468,
#   211,
#   532,
#   2740,
#   455,
#   730,
#   7985,
#   368,
#   1242,
#   3507,
#   32,
#   2268,
#   103,
#   574,
#   836,
#   12624,
#   183,
#   6,
#   2518,
#   404,
#   7299,
#   748,
#   3186,
#   1303,
#   3776],
#  [383,
#   226,
#   240,
#   852,
#   241,
#   170,
#   145,
#   2430,
#   189,
#   694,
#   3533,
#   47,
#   1059,
#   748,
#   1752,
#   13,
#   9683,
#   258,
#   7,
#   383,
#   226,
#   240,
#   852,
#   241,
#   170],
#  [1052,
#   4051,
#   5,
#   407,
#   42,
#   295,
#   145,
#   1220,
#   174,
#   838,
#   73,
#   2,
#   1052,
#   4051,
#   5,
#   407,
#   42,
#   295,
#   145,
#   1220,
#   174,
#   838,
#   73,
#   2,
#   1052],
#  [54,
#   18,
#   3053,
#   45,
#   2875,
#   1324,
#   3202,
#   50,
#   3145,
#   1354,
#   1263,
#   58,
#   400,
#   3871,
#   2003,
#   4831,
#   3392,
#   45,
#   405,
#   2875,
#   10,
#   3053,
#   5,
#   14,
#   2167],
#  [92,
#   686,
#   416,
#   847,
#   61,
#   2,
#   428,
#   1136,
#   6,
#   1419,
#   924,
#   614,
#   1500,
#   6965,
#   29,
#   35,
#   92,
#   686,
#   416,
#   847,
#   61,
#   2,
#   428,
#   1136,
#   6],
#  [793,
#   429,
#   237,
#   431,
#   6,
#   762,
#   8465,
#   3720,
#   3721,
#   33,
#   1102,
#   2680,
#   839,
#   864,
#   97,
#   5,
#   2,
#   1210,
#   406,
#   14,
#   13029,
#   6048,
#   19,
#   26,
#   681],
#  [173,
#   479,
#   338,
#   1097,
#   303,
#   300,
#   69,
#   619,
#   1790,
#   126,
#   459,
#   1225,
#   268,
#   5422,
#   109,
#   889,
#   5420,
#   459,
#   1309,
#   721,
#   1512,
#   21,
#   102,
#   5,
#   2496],
#  [156,
#   10,
#   5,
#   850,
#   10725,
#   721,
#   1512,
#   6105,
#   294,
#   168,
#   6592,
#   2736,
#   2093,
#   10,
#   3123,
#   294,
#   5,
#   14,
#   113,
#   119,
#   98,
#   20,
#   1118,
#   11,
#   113],
#  [174,
#   117,
#   502,
#   14366,
#   112,
#   1434,
#   569,
#   1788,
#   4226,
#   851,
#   86,
#   300,
#   600,
#   29,
#   35,
#   174,
#   117,
#   502,
#   14366,
#   112,
#   1434,
#   569,
#   1788,
#   4226,
#   851],
#  [184,
#   964,
#   1788,
#   403,
#   1042,
#   10,
#   19,
#   79,
#   2328,
#   93,
#   204,
#   184,
#   964,
#   1788,
#   403,
#   1042,
#   10,
#   19,
#   79,
#   2328,
#   93,
#   204,
#   184,
#   964,
#   1788],
#  [3,
#   249,
#   1539,
#   3403,
#   13469,
#   1229,
#   928,
#   8,
#   6201,
#   928,
#   3570,
#   1229,
#   935,
#   34,
#   1520,
#   21,
#   375,
#   3157,
#   232,
#   2853,
#   3,
#   249,
#   1539,
#   3403,
#   13469],
#  [8,
#   11,
#   168,
#   244,
#   85,
#   1958,
#   80,
#   1081,
#   257,
#   244,
#   199,
#   168,
#   8,
#   7,
#   236,
#   184,
#   161,
#   1,
#   5040,
#   71,
#   12,
#   1,
#   8,
#   638,
#   85],
#  [377,
#   2053,
#   2265,
#   564,
#   287,
#   125,
#   903,
#   890,
#   6012,
#   4237,
#   2674,
#   44,
#   8727,
#   5502,
#   63,
#   426,
#   518,
#   10367,
#   1982,
#   1130,
#   29,
#   35,
#   377,
#   2053,
#   2265],
#  [1904,
#   218,
#   7685,
#   2858,
#   2736,
#   599,
#   2175,
#   45,
#   1109,
#   1232,
#   787,
#   4886,
#   522,
#   969,
#   264,
#   2534,
#   7,
#   385,
#   130,
#   734,
#   1904,
#   218,
#   7685,
#   2858,
#   2736],
#  [133,
#   954,
#   884,
#   368,
#   15,
#   591,
#   115,
#   34,
#   63,
#   58,
#   744,
#   92,
#   30,
#   256,
#   1402,
#   2099,
#   129,
#   409,
#   2668,
#   3862,
#   186,
#   133,
#   954,
#   884,
#   368],
#  [502,
#   287,
#   4407,
#   180,
#   5014,
#   1045,
#   810,
#   800,
#   1358,
#   894,
#   91,
#   2990,
#   228,
#   3015,
#   1079,
#   614,
#   167,
#   29,
#   35,
#   502,
#   287,
#   4407,
#   180,
#   5014,
#   1045],
#  [271,
#   716,
#   6,
#   10870,
#   2187,
#   687,
#   1153,
#   1733,
#   786,
#   87,
#   8103,
#   687,
#   271,
#   15,
#   786,
#   5,
#   87,
#   271,
#   405,
#   6965,
#   463,
#   175,
#   587,
#   1822,
#   8596],
#  [11,
#   3231,
#   257,
#   244,
#   3,
#   11,
#   1475,
#   15,
#   1978,
#   1629,
#   77,
#   19,
#   7,
#   4116,
#   2754,
#   13651,
#   7529,
#   10080,
#   5301,
#   11,
#   3231,
#   257,
#   244,
#   3,
#   11],
#  [92,
#   815,
#   142,
#   256,
#   2238,
#   2516,
#   12121,
#   17,
#   1677,
#   575,
#   334,
#   22,
#   617,
#   3026,
#   753,
#   3473,
#   1,
#   356,
#   162,
#   457,
#   183,
#   842,
#   154,
#   32,
#   30],
#  [2392,
#   11590,
#   297,
#   1950,
#   1361,
#   1714,
#   507,
#   89,
#   9134,
#   1950,
#   26,
#   1,
#   2776,
#   2392,
#   57,
#   249,
#   897,
#   7649,
#   920,
#   39,
#   450,
#   2392,
#   11590,
#   297,
#   1950],
#  [4507,
#   85,
#   40,
#   1923,
#   14201,
#   17,
#   238,
#   1234,
#   12303,
#   3587,
#   11557,
#   4103,
#   5015,
#   16,
#   1,
#   869,
#   502,
#   45,
#   2392,
#   11998,
#   14248,
#   6437,
#   85,
#   91,
#   3562],
#  [1,
#   77,
#   1488,
#   12492,
#   72,
#   2153,
#   19,
#   5,
#   8,
#   151,
#   39,
#   1,
#   77,
#   1488,
#   12492,
#   72,
#   2153,
#   19,
#   5,
#   8,
#   151,
#   39,
#   1,
#   77,
#   1488],
#  [92,
#   1968,
#   2607,
#   1367,
#   4266,
#   40,
#   6367,
#   7813,
#   8,
#   138,
#   1143,
#   9278,
#   107,
#   13088,
#   2327,
#   638,
#   525,
#   595,
#   5998,
#   624,
#   365,
#   3174,
#   8749,
#   209,
#   17],
#  [8,
#   85,
#   2692,
#   8521,
#   8,
#   240,
#   1562,
#   17,
#   858,
#   3982,
#   89,
#   3,
#   68,
#   53,
#   26,
#   3771,
#   6,
#   17,
#   525,
#   330,
#   359,
#   17,
#   1,
#   131,
#   57],
#  [2040,
#   660,
#   1,
#   17,
#   15,
#   236,
#   5,
#   883,
#   98,
#   3,
#   2,
#   44,
#   34,
#   617,
#   12,
#   8521,
#   427,
#   1,
#   2343,
#   526,
#   7,
#   17,
#   2691,
#   3771,
#   6],
#  [87,
#   6782,
#   871,
#   22,
#   1983,
#   3493,
#   426,
#   374,
#   2,
#   1445,
#   346,
#   2820,
#   9989,
#   1658,
#   2983,
#   119,
#   2984,
#   29,
#   35,
#   87,
#   6782,
#   871,
#   22,
#   1983,
#   3493],
#  [6,
#   6,
#   13,
#   371,
#   643,
#   704,
#   70,
#   5,
#   1326,
#   1276,
#   22,
#   11,
#   12,
#   21,
#   132,
#   235,
#   6,
#   6,
#   13,
#   371,
#   643,
#   704,
#   70,
#   5,
#   1326],
#  [1246,
#   283,
#   15,
#   72,
#   1924,
#   24,
#   4612,
#   405,
#   107,
#   218,
#   11664,
#   1224,
#   93,
#   734,
#   1246,
#   283,
#   15,
#   72,
#   1924,
#   24,
#   4612,
#   405,
#   107,
#   218,
#   11664],
#  [8,
#   482,
#   95,
#   1741,
#   20,
#   11547,
#   2038,
#   34,
#   3103,
#   2309,
#   8,
#   26,
#   2814,
#   254,
#   51,
#   6,
#   568,
#   134,
#   789,
#   1638,
#   2040,
#   1306,
#   308,
#   2853,
#   27],
#  [1096,
#   286,
#   568,
#   3,
#   13174,
#   18,
#   223,
#   1109,
#   318,
#   17,
#   682,
#   1248,
#   13,
#   1310,
#   1,
#   323,
#   393,
#   615,
#   2892,
#   682,
#   3316,
#   520,
#   5840,
#   2343,
#   29],
#  [2484,
#   6,
#   1,
#   3102,
#   223,
#   252,
#   14384,
#   1261,
#   38,
#   2999,
#   1737,
#   1782,
#   2089,
#   969,
#   153,
#   2,
#   13361,
#   2575,
#   18,
#   821,
#   8341,
#   11,
#   551,
#   1119,
#   2472],
#  [704,
#   578,
#   10356,
#   104,
#   5,
#   3658,
#   102,
#   4575,
#   2842,
#   1143,
#   2851,
#   1945,
#   870,
#   7806,
#   456,
#   17,
#   1703,
#   590,
#   93,
#   331,
#   2954,
#   213,
#   37,
#   1328,
#   704],
#  [2,
#   1661,
#   7603,
#   2148,
#   500,
#   27,
#   1513,
#   1261,
#   254,
#   2508,
#   170,
#   296,
#   10733,
#   6031,
#   2334,
#   6,
#   2328,
#   561,
#   724,
#   68,
#   50,
#   2380,
#   633,
#   60,
#   37],
#  [646,
#   18,
#   2188,
#   1,
#   3870,
#   1261,
#   27,
#   12,
#   1045,
#   1513,
#   10,
#   42,
#   1261,
#   1404,
#   1661,
#   23,
#   359,
#   106,
#   207,
#   79,
#   14,
#   2408,
#   181,
#   36,
#   79],
#  [12,
#   2538,
#   3,
#   7304,
#   16,
#   1,
#   394,
#   2441,
#   720,
#   1315,
#   3,
#   16,
#   5419,
#   69,
#   711,
#   418,
#   3303,
#   1892,
#   6318,
#   4459,
#   4636,
#   260,
#   876,
#   174,
#   646],
#  [34,
#   303,
#   6285,
#   179,
#   23,
#   2488,
#   8320,
#   5,
#   11,
#   22,
#   1,
#   71,
#   720,
#   11,
#   18,
#   2148,
#   261,
#   18,
#   1,
#   1,
#   293,
#   3484,
#   2,
#   34,
#   303],
#  [818,
#   44,
#   22,
#   3092,
#   28,
#   87,
#   3219,
#   52,
#   176,
#   2576,
#   643,
#   417,
#   426,
#   386,
#   14287,
#   705,
#   285,
#   167,
#   7,
#   101,
#   41,
#   818,
#   44,
#   22,
#   3092],
#  [40,
#   58,
#   1382,
#   12,
#   109,
#   500,
#   4735,
#   60,
#   14,
#   1488,
#   1275,
#   2,
#   257,
#   44,
#   17,
#   22,
#   5,
#   2081,
#   10,
#   12,
#   90,
#   40,
#   420,
#   30,
#   210],
#  [134,
#   1863,
#   677,
#   302,
#   115,
#   24,
#   3468,
#   937,
#   188,
#   934,
#   119,
#   4,
#   134,
#   1863,
#   677,
#   302,
#   115,
#   24,
#   3468,
#   937,
#   188,
#   934,
#   119,
#   4,
#   134],
#  [307,
#   3630,
#   3514,
#   1920,
#   569,
#   325,
#   19,
#   601,
#   6,
#   11720,
#   1199,
#   107,
#   428,
#   1111,
#   1481,
#   3,
#   3268,
#   7649,
#   1007,
#   5780,
#   1366,
#   9432,
#   229,
#   319,
#   6650],
#  [111,
#   681,
#   35,
#   10,
#   47,
#   2378,
#   247,
#   2690,
#   706,
#   537,
#   1011,
#   131,
#   1629,
#   6652,
#   247,
#   2828,
#   44,
#   1692,
#   1591,
#   1476,
#   29,
#   35,
#   80,
#   111,
#   681],
#  [13,
#   751,
#   77,
#   7,
#   36,
#   2097,
#   287,
#   6601,
#   2032,
#   10733,
#   6031,
#   5,
#   950,
#   674,
#   476,
#   352,
#   13,
#   751,
#   77,
#   7,
#   36,
#   2097,
#   287,
#   6601,
#   2032],
#  [344,
#   13009,
#   21,
#   331,
#   91,
#   360,
#   247,
#   5,
#   525,
#   6601,
#   170,
#   500,
#   344,
#   13009,
#   21,
#   331,
#   91,
#   360,
#   247,
#   5,
#   525,
#   6601,
#   170,
#   500,
#   344],
#  [18,
#   646,
#   3,
#   2784,
#   1,
#   406,
#   7045,
#   2074,
#   573,
#   293,
#   1,
#   18,
#   1870,
#   7142,
#   21,
#   2,
#   18,
#   646,
#   3,
#   2784,
#   1,
#   406,
#   7045,
#   2074,
#   573],
#  [3,
#   683,
#   19,
#   85,
#   2436,
#   4042,
#   404,
#   679,
#   359,
#   16,
#   95,
#   905,
#   228,
#   3,
#   85,
#   10,
#   5,
#   77,
#   332,
#   1492,
#   34,
#   552,
#   1585,
#   7,
#   1109],
#  [8,
#   25,
#   7763,
#   14,
#   2700,
#   5,
#   2148,
#   2076,
#   1244,
#   778,
#   253,
#   10212,
#   349,
#   194,
#   14,
#   119,
#   1,
#   410,
#   13,
#   11242,
#   5,
#   7400,
#   8,
#   7,
#   8],
#  [5840,
#   11,
#   566,
#   232,
#   212,
#   119,
#   7037,
#   5840,
#   476,
#   69,
#   1633,
#   4822,
#   549,
#   13,
#   217,
#   2513,
#   1473,
#   2693,
#   1230,
#   53,
#   3,
#   3093,
#   2462,
#   893,
#   966],
#  [1538,
#   1205,
#   13,
#   217,
#   3,
#   1,
#   1514,
#   1317,
#   372,
#   583,
#   1890,
#   1301,
#   2902,
#   448,
#   1253,
#   4310,
#   392,
#   1890,
#   1301,
#   4441,
#   14166,
#   29,
#   6937,
#   1538,
#   1205],
#  [259,
#   18,
#   1965,
#   233,
#   365,
#   272,
#   1169,
#   2064,
#   6727,
#   2849,
#   587,
#   2630,
#   1516,
#   1164,
#   222,
#   59,
#   283,
#   4602,
#   316,
#   144,
#   114,
#   1511,
#   196,
#   2760,
#   248],
#  [500,
#   359,
#   1430,
#   1942,
#   6090,
#   96,
#   82,
#   29,
#   1657,
#   500,
#   359,
#   1430,
#   1942,
#   6090,
#   96,
#   82,
#   29,
#   1657,
#   500,
#   359,
#   1430,
#   1942,
#   6090,
#   96,
#   82],
#  [3,
#   13254,
#   338,
#   757,
#   519,
#   887,
#   168,
#   305,
#   476,
#   69,
#   489,
#   61,
#   539,
#   144,
#   114,
#   519,
#   1511,
#   196,
#   2760,
#   1705,
#   8439,
#   684,
#   4390,
#   96,
#   18],
#  [3,
#   1581,
#   18,
#   5358,
#   6956,
#   2237,
#   126,
#   2597,
#   4675,
#   857,
#   583,
#   12,
#   11673,
#   720,
#   232,
#   446,
#   4434,
#   1821,
#   4675,
#   59,
#   4908,
#   217,
#   583,
#   5493,
#   29],
#  [3,
#   243,
#   8753,
#   8405,
#   123,
#   1254,
#   431,
#   271,
#   852,
#   109,
#   1797,
#   59,
#   82,
#   757,
#   1162,
#   1030,
#   432,
#   547,
#   210,
#   1585,
#   15,
#   625,
#   1521,
#   1912,
#   360],
#  [43,
#   338,
#   5,
#   14348,
#   3011,
#   884,
#   7,
#   2,
#   43,
#   338,
#   5,
#   14348,
#   3011,
#   884,
#   7,
#   2,
#   43,
#   338,
#   5,
#   14348,
#   3011,
#   884,
#   7,
#   2,
#   43],
#  [85,
#   2077,
#   140,
#   7513,
#   2360,
#   617,
#   3011,
#   4,
#   54,
#   2,
#   673,
#   182,
#   3011,
#   8753,
#   85,
#   2077,
#   140,
#   7513,
#   2360,
#   617,
#   3011,
#   4,
#   54,
#   2,
#   673],
#  [3,
#   1121,
#   491,
#   14142,
#   1288,
#   48,
#   1031,
#   746,
#   2145,
#   1,
#   155,
#   4895,
#   674,
#   1585,
#   18,
#   181,
#   122,
#   18,
#   34,
#   24,
#   7,
#   36,
#   3,
#   1121,
#   491],
#  [58,
#   1049,
#   3,
#   221,
#   4450,
#   1383,
#   12122,
#   1290,
#   1290,
#   13386,
#   180,
#   364,
#   733,
#   13,
#   65,
#   2876,
#   955,
#   84,
#   21,
#   331,
#   58,
#   1049,
#   3,
#   221,
#   4450],
#  [23,
#   725,
#   1,
#   725,
#   50,
#   241,
#   435,
#   747,
#   911,
#   2283,
#   272,
#   13,
#   24,
#   93,
#   331,
#   23,
#   725,
#   1,
#   725,
#   50,
#   241,
#   435,
#   747,
#   911,
#   2283],
#  [3,
#   25,
#   1019,
#   1028,
#   647,
#   3,
#   25,
#   843,
#   73,
#   37,
#   146,
#   3,
#   25,
#   1019,
#   1028,
#   647,
#   3,
#   25,
#   843,
#   73,
#   37,
#   146,
#   3,
#   25,
#   1019],
#  [254,
#   525,
#   3,
#   1121,
#   1,
#   1493,
#   423,
#   1374,
#   331,
#   254,
#   525,
#   3,
#   1121,
#   1,
#   1493,
#   423,
#   1374,
#   331,
#   254,
#   525,
#   3,
#   1121,
#   1,
#   1493,
#   423],
#  [86,
#   283,
#   3,
#   1415,
#   623,
#   283,
#   1243,
#   471,
#   4,
#   17,
#   256,
#   86,
#   283,
#   3,
#   1415,
#   623,
#   283,
#   1243,
#   471,
#   4,
#   17,
#   256,
#   86,
#   283,
#   3],
#  [3,
#   1747,
#   6646,
#   4626,
#   39,
#   2162,
#   8253,
#   125,
#   5,
#   888,
#   3218,
#   644,
#   7,
#   2,
#   3,
#   1747,
#   6646,
#   4626,
#   39,
#   2162,
#   8253,
#   125,
#   5,
#   888,
#   3218],
#  [3,
#   57,
#   1,
#   138,
#   8,
#   1,
#   662,
#   88,
#   12,
#   758,
#   14,
#   481,
#   73,
#   331,
#   3,
#   57,
#   1,
#   138,
#   8,
#   1,
#   662,
#   88,
#   12,
#   758,
#   14],
#  [42,
#   481,
#   8,
#   57,
#   105,
#   39,
#   2821,
#   12,
#   156,
#   39,
#   316,
#   20,
#   1054,
#   1147,
#   21,
#   2,
#   42,
#   481,
#   8,
#   57,
#   105,
#   39,
#   2821,
#   12,
#   156],
#  [3076,
#   5,
#   1562,
#   3652,
#   3337,
#   155,
#   26,
#   42,
#   117,
#   12,
#   11,
#   278,
#   18,
#   6382,
#   2,
#   172,
#   1298,
#   7,
#   2,
#   73,
#   122,
#   3076,
#   5,
#   1562,
#   3652],
#  [58,
#   1371,
#   140,
#   2608,
#   3164,
#   3417,
#   3418,
#   3356,
#   3671,
#   2189,
#   2252,
#   3306,
#   862,
#   29,
#   3578,
#   58,
#   1371,
#   140,
#   2608,
#   3164,
#   3417,
#   3418,
#   3356,
#   3671,
#   2189],
#  [17,
#   5762,
#   822,
#   8,
#   13507,
#   65,
#   203,
#   8,
#   43,
#   50,
#   3801,
#   20,
#   2731,
#   11085,
#   2020,
#   156,
#   2681,
#   42,
#   47,
#   452,
#   12,
#   26,
#   5134,
#   605,
#   529],
#  [3,
#   860,
#   2783,
#   1,
#   6860,
#   1494,
#   2138,
#   90,
#   535,
#   696,
#   106,
#   232,
#   111,
#   248,
#   31,
#   136,
#   858,
#   5004,
#   2730,
#   3706,
#   828,
#   263,
#   746,
#   1803,
#   60],
#  [406,
#   1464,
#   825,
#   10,
#   99,
#   1800,
#   3,
#   76,
#   476,
#   69,
#   392,
#   3467,
#   45,
#   93,
#   331,
#   406,
#   1464,
#   825,
#   10,
#   99,
#   1800,
#   3,
#   76,
#   476,
#   69],
#  [15,
#   190,
#   7085,
#   1800,
#   1066,
#   27,
#   2569,
#   460,
#   36,
#   15,
#   190,
#   7085,
#   1800,
#   1066,
#   27,
#   2569,
#   460,
#   36,
#   15,
#   190,
#   7085,
#   1800,
#   1066,
#   27,
#   2569],
#  [349,
#   1631,
#   384,
#   1843,
#   1227,
#   201,
#   2099,
#   566,
#   7,
#   2,
#   349,
#   1631,
#   384,
#   1843,
#   1227,
#   201,
#   2099,
#   566,
#   7,
#   2,
#   349,
#   1631,
#   384,
#   1843,
#   1227],
#  [3,
#   1415,
#   649,
#   1134,
#   1367,
#   23,
#   1620,
#   51,
#   5752,
#   4253,
#   1606,
#   1674,
#   11,
#   13,
#   117,
#   3011,
#   73,
#   2,
#   3,
#   1415,
#   649,
#   1134,
#   1367,
#   23,
#   1620],
#  [8,
#   2565,
#   2665,
#   938,
#   1968,
#   4834,
#   28,
#   2665,
#   379,
#   23,
#   7,
#   331,
#   8,
#   2565,
#   2665,
#   938,
#   1968,
#   4834,
#   28,
#   2665,
#   379,
#   23,
#   7,
#   331,
#   8],
#  [1276,
#   390,
#   1535,
#   2665,
#   2115,
#   13914,
#   384,
#   566,
#   1227,
#   7,
#   331,
#   1276,
#   390,
#   1535,
#   2665,
#   2115,
#   13914,
#   384,
#   566,
#   1227,
#   7,
#   331,
#   1276,
#   390,
#   1535],
#  [3,
#   257,
#   1784,
#   13161,
#   566,
#   7,
#   2,
#   3,
#   257,
#   1784,
#   13161,
#   566,
#   7,
#   2,
#   3,
#   257,
#   1784,
#   13161,
#   566,
#   7,
#   2,
#   3,
#   257,
#   1784,
#   13161],
#  [13,
#   152,
#   67,
#   152,
#   1928,
#   300,
#   1993,
#   7379,
#   126,
#   2125,
#   2312,
#   4748,
#   3022,
#   1015,
#   617,
#   8753,
#   217,
#   4748,
#   82,
#   93,
#   331,
#   13,
#   152,
#   67,
#   152],
#  [27,
#   254,
#   510,
#   126,
#   3599,
#   510,
#   69,
#   2359,
#   69,
#   2357,
#   415,
#   3712,
#   192,
#   42,
#   326,
#   851,
#   534,
#   165,
#   109,
#   82,
#   1875,
#   1617,
#   589,
#   122,
#   3405],
#  [15,
#   11363,
#   266,
#   3011,
#   520,
#   198,
#   192,
#   1928,
#   520,
#   3884,
#   791,
#   1,
#   4171,
#   1,
#   410,
#   266,
#   8962,
#   3235,
#   1688,
#   1769,
#   2853,
#   13787,
#   333,
#   11,
#   11363],
#  [72,
#   71,
#   1098,
#   18,
#   28,
#   699,
#   1,
#   6860,
#   8,
#   368,
#   2969,
#   92,
#   28,
#   7,
#   331,
#   72,
#   71,
#   1098,
#   18,
#   28,
#   699,
#   1,
#   6860,
#   8,
#   368],
#  [3,
#   1,
#   1079,
#   5787,
#   825,
#   8753,
#   479,
#   10,
#   31,
#   5,
#   504,
#   43,
#   184,
#   7,
#   2,
#   3,
#   1,
#   1079,
#   5787,
#   825,
#   8753,
#   479,
#   10,
#   31,
#   5],
#  [8,
#   1,
#   58,
#   744,
#   853,
#   58,
#   6860,
#   101,
#   2408,
#   20,
#   19,
#   293,
#   12362,
#   1020,
#   331,
#   8,
#   1,
#   58,
#   744,
#   853,
#   58,
#   6860,
#   101,
#   2408,
#   20],
#  [18,
#   853,
#   1423,
#   18,
#   751,
#   10,
#   413,
#   233,
#   8750,
#   3308,
#   471,
#   7170,
#   1423,
#   3,
#   323,
#   196,
#   556,
#   300,
#   3745,
#   1207,
#   69,
#   160,
#   121,
#   73,
#   36],
#  [511,
#   346,
#   191,
#   3994,
#   92,
#   5,
#   2,
#   95,
#   255,
#   148,
#   70,
#   63,
#   1523,
#   1421,
#   463,
#   175,
#   955,
#   786,
#   1,
#   1419,
#   60,
#   101,
#   41,
#   511,
#   346],
#  [3,
#   25,
#   1028,
#   1054,
#   3,
#   240,
#   1104,
#   623,
#   20,
#   65,
#   16,
#   1534,
#   7,
#   3,
#   25,
#   1028,
#   1054,
#   3,
#   240,
#   1104,
#   623,
#   20,
#   65,
#   16,
#   1534],
#  [893,
#   359,
#   85,
#   882,
#   136,
#   987,
#   3,
#   4928,
#   6743,
#   2143,
#   331,
#   14,
#   7796,
#   65,
#   705,
#   75,
#   5016,
#   893,
#   359,
#   85,
#   882,
#   136,
#   987,
#   3,
#   4928],
#  [808,
#   5742,
#   142,
#   598,
#   452,
#   1850,
#   410,
#   282,
#   166,
#   10,
#   2035,
#   63,
#   499,
#   484,
#   808,
#   195,
#   587,
#   1178,
#   203,
#   4511,
#   4206,
#   569,
#   586,
#   7247,
#   484],
#  [20,
#   4174,
#   1187,
#   1609,
#   13,
#   2132,
#   25,
#   643,
#   2916,
#   1433,
#   720,
#   280,
#   114,
#   319,
#   113,
#   501,
#   6923,
#   2076,
#   413,
#   683,
#   22,
#   244,
#   1187,
#   695,
#   1318],
#  [8,
#   43,
#   107,
#   761,
#   49,
#   25,
#   1,
#   711,
#   1187,
#   695,
#   1799,
#   711,
#   1187,
#   856,
#   1137,
#   6259,
#   8,
#   43,
#   107,
#   761,
#   49,
#   25,
#   1,
#   711,
#   1187],
#  [1,
#   257,
#   250,
#   458,
#   195,
#   12,
#   1,
#   2626,
#   5944,
#   1055,
#   89,
#   107,
#   453,
#   403,
#   25,
#   1482,
#   1720,
#   19,
#   107,
#   66,
#   639,
#   920,
#   66,
#   3164,
#   92],
#  [606,
#   1,
#   2448,
#   3722,
#   238,
#   1,
#   1562,
#   5820,
#   224,
#   1873,
#   213,
#   9128,
#   7,
#   2570,
#   606,
#   1,
#   2448,
#   3722,
#   238,
#   1,
#   1562,
#   5820,
#   224,
#   1873,
#   213],
#  [3,
#   369,
#   313,
#   215,
#   452,
#   361,
#   4549,
#   238,
#   2325,
#   1092,
#   1392,
#   13,
#   303,
#   2325,
#   2683,
#   13,
#   2222,
#   1392,
#   1156,
#   6845,
#   664,
#   72,
#   4549,
#   238,
#   1],
#  [247,
#   8,
#   123,
#   77,
#   6,
#   14,
#   1866,
#   8,
#   1,
#   2309,
#   2052,
#   161,
#   736,
#   5106,
#   20,
#   80,
#   745,
#   8,
#   2155,
#   10118,
#   10119,
#   87,
#   77,
#   656,
#   39],
#  [54,
#   3,
#   44,
#   86,
#   2092,
#   18,
#   132,
#   272,
#   394,
#   12,
#   5502,
#   13,
#   31,
#   3,
#   68,
#   872,
#   53,
#   3,
#   1062,
#   63,
#   77,
#   92,
#   2838,
#   30,
#   5086],
#  [2637,
#   117,
#   8,
#   138,
#   134,
#   761,
#   42,
#   761,
#   679,
#   45,
#   288,
#   58,
#   6755,
#   6,
#   69,
#   3,
#   79,
#   883,
#   79,
#   3,
#   6280,
#   6183,
#   6280,
#   7926,
#   6280],
#  [5550,
#   191,
#   1058,
#   798,
#   313,
#   22,
#   979,
#   921,
#   665,
#   4533,
#   4505,
#   921,
#   2948,
#   35,
#   5550,
#   191,
#   1058,
#   798,
#   313,
#   22,
#   979,
#   921,
#   665,
#   4533,
#   4505],
#  [129,
#   225,
#   198,
#   839,
#   798,
#   1950,
#   78,
#   322,
#   11254,
#   3140,
#   2167,
#   5739,
#   10175,
#   11031,
#   1,
#   449,
#   19,
#   12237,
#   1923,
#   3831,
#   841,
#   450,
#   14022,
#   29,
#   35],
#  [270,
#   2743,
#   141,
#   2612,
#   7821,
#   6,
#   397,
#   29,
#   35,
#   270,
#   2743,
#   141,
#   2612,
#   7821,
#   6,
#   397,
#   29,
#   35,
#   270,
#   2743,
#   141,
#   2612,
#   7821,
#   6,
#   397],
#  [120,
#   7149,
#   518,
#   4952,
#   302,
#   232,
#   96,
#   16,
#   1,
#   2698,
#   399,
#   396,
#   1744,
#   1548,
#   65,
#   59,
#   899,
#   29,
#   142,
#   5848,
#   4209,
#   1117,
#   2240,
#   2121,
#   697],
#  [1012,
#   117,
#   8,
#   8,
#   1165,
#   17,
#   1363,
#   80,
#   20,
#   399,
#   276,
#   52,
#   8,
#   435,
#   7051,
#   21,
#   1012,
#   117,
#   8,
#   8,
#   1165,
#   17,
#   1363,
#   80,
#   20],
#  [1286,
#   123,
#   2222,
#   131,
#   45,
#   778,
#   6224,
#   10006,
#   1739,
#   12,
#   250,
#   2312,
#   890,
#   1134,
#   168,
#   1545,
#   3433,
#   6704,
#   576,
#   692,
#   954,
#   10013,
#   6692,
#   2312,
#   29],
#  [1633,
#   127,
#   11,
#   213,
#   1397,
#   9128,
#   11,
#   2863,
#   2414,
#   2025,
#   9614,
#   11,
#   1,
#   13757,
#   43,
#   45,
#   93,
#   1470,
#   1633,
#   127,
#   11,
#   213,
#   1397,
#   9128,
#   11],
#  [6224,
#   87,
#   3438,
#   203,
#   519,
#   512,
#   598,
#   33,
#   5,
#   3231,
#   13,
#   6224,
#   107,
#   1096,
#   19,
#   685,
#   6,
#   2842,
#   15,
#   4469,
#   20,
#   512,
#   2482,
#   340,
#   198],
#  [452,
#   1896,
#   361,
#   91,
#   90,
#   1202,
#   559,
#   287,
#   13,
#   2222,
#   559,
#   1,
#   1848,
#   720,
#   481,
#   5,
#   2861,
#   489,
#   143,
#   3011,
#   106,
#   12,
#   1,
#   143,
#   160],
#  [8,
#   3178,
#   11,
#   2127,
#   2,
#   1974,
#   39,
#   8,
#   3178,
#   11,
#   2127,
#   2,
#   1974,
#   39,
#   8,
#   3178,
#   11,
#   2127,
#   2,
#   1974,
#   39,
#   8,
#   3178,
#   11,
#   2127],
#  [3,
#   250,
#   14367,
#   591,
#   11,
#   958,
#   2909,
#   3,
#   1,
#   822,
#   2,
#   3,
#   250,
#   14367,
#   591,
#   11,
#   958,
#   2909,
#   3,
#   1,
#   822,
#   2,
#   3,
#   250,
#   14367],
#  [8,
#   63,
#   3904,
#   2191,
#   438,
#   229,
#   5,
#   57,
#   2048,
#   1567,
#   1533,
#   3,
#   2,
#   780,
#   638,
#   400,
#   1102,
#   481,
#   5106,
#   193,
#   8,
#   58,
#   906,
#   3,
#   2],
#  [2851,
#   252,
#   5021,
#   2716,
#   995,
#   1349,
#   84,
#   2716,
#   7,
#   4192,
#   2851,
#   252,
#   5021,
#   2716,
#   995,
#   1349,
#   84,
#   2716,
#   7,
#   4192,
#   2851,
#   252,
#   5021,
#   2716,
#   995],
#  [508,
#   11,
#   954,
#   9134,
#   994,
#   5167,
#   7,
#   2,
#   73,
#   433,
#   954,
#   3546,
#   1322,
#   1136,
#   7395,
#   954,
#   1878,
#   270,
#   1561,
#   508,
#   11,
#   954,
#   9134,
#   994,
#   5167],
#  [8,
#   1576,
#   14,
#   420,
#   4408,
#   647,
#   65,
#   3055,
#   23,
#   174,
#   2974,
#   65,
#   610,
#   352,
#   23,
#   4,
#   37,
#   4398,
#   759,
#   8,
#   1576,
#   14,
#   420,
#   4408,
#   647],
#  [995,
#   1,
#   643,
#   519,
#   100,
#   2716,
#   1349,
#   4,
#   4192,
#   995,
#   1,
#   643,
#   519,
#   100,
#   2716,
#   1349,
#   4,
#   4192,
#   995,
#   1,
#   643,
#   519,
#   100,
#   2716,
#   1349],
#  [3,
#   1095,
#   61,
#   266,
#   372,
#   1140,
#   253,
#   287,
#   12,
#   1,
#   34,
#   3,
#   593,
#   905,
#   34,
#   19,
#   16,
#   1518,
#   372,
#   61,
#   398,
#   7,
#   47,
#   2523,
#   3],
#  [864,
#   66,
#   19,
#   11,
#   810,
#   864,
#   66,
#   3942,
#   781,
#   5,
#   19,
#   13,
#   695,
#   2732,
#   383,
#   372,
#   11,
#   714,
#   4192,
#   31,
#   10,
#   191,
#   258,
#   327,
#   864],
#  [532,
#   1882,
#   1071,
#   967,
#   153,
#   68,
#   53,
#   68,
#   157,
#   83,
#   1095,
#   426,
#   494,
#   14,
#   2887,
#   164,
#   923,
#   967,
#   450,
#   532,
#   1882,
#   1071,
#   967,
#   153,
#   68],
#  [280,
#   9857,
#   7058,
#   8,
#   659,
#   226,
#   1080,
#   74,
#   11,
#   3,
#   174,
#   18,
#   140,
#   9857,
#   2270,
#   9857,
#   11,
#   2317,
#   12497,
#   1210,
#   112,
#   203,
#   7116,
#   3,
#   11],
#  [8,
#   2,
#   5288,
#   2,
#   3409,
#   14,
#   231,
#   7,
#   37,
#   48,
#   146,
#   673,
#   182,
#   537,
#   36,
#   8,
#   2,
#   5288,
#   2,
#   3409,
#   14,
#   231,
#   7,
#   37,
#   48],
#  [3,
#   1,
#   2,
#   5191,
#   76,
#   769,
#   3278,
#   203,
#   2,
#   1,
#   769,
#   7,
#   2,
#   73,
#   23,
#   1062,
#   1696,
#   13,
#   453,
#   211,
#   3,
#   1,
#   2,
#   5191,
#   76],
#  [1,
#   15,
#   184,
#   226,
#   134,
#   1866,
#   8,
#   293,
#   85,
#   630,
#   188,
#   2132,
#   314,
#   8,
#   498,
#   8,
#   349,
#   3,
#   180,
#   321,
#   34,
#   116,
#   1042,
#   77,
#   92],
#  [379,
#   5,
#   76,
#   3,
#   38,
#   25,
#   925,
#   572,
#   358,
#   231,
#   495,
#   76,
#   82,
#   86,
#   138,
#   3694,
#   210,
#   521,
#   3689,
#   2477,
#   535,
#   109,
#   575,
#   247,
#   767],
#  [91,
#   34,
#   1091,
#   13424,
#   2190,
#   2758,
#   14,
#   315,
#   535,
#   749,
#   13,
#   247,
#   2795,
#   378,
#   14,
#   1091,
#   11,
#   16,
#   2253,
#   77,
#   116,
#   3,
#   16,
#   3817,
#   79],
#  [11,
#   2909,
#   1579,
#   898,
#   27,
#   716,
#   2676,
#   1933,
#   3053,
#   1490,
#   737,
#   29,
#   324,
#   142,
#   1135,
#   247,
#   11,
#   2909,
#   1579,
#   898,
#   27,
#   716,
#   2676,
#   1933,
#   3053],
#  [3,
#   263,
#   22,
#   25,
#   1204,
#   14,
#   2924,
#   8894,
#   5898,
#   8,
#   98,
#   156,
#   244,
#   5049,
#   282,
#   628,
#   138,
#   11,
#   1,
#   400,
#   7,
#   375,
#   324,
#   304,
#   1598],
#  [2,
#   5191,
#   4831,
#   147,
#   1242,
#   18,
#   1023,
#   117,
#   2,
#   2758,
#   18,
#   4861,
#   231,
#   9332,
#   58,
#   184,
#   31,
#   7,
#   331,
#   2,
#   5191,
#   4831,
#   147,
#   1242,
#   18],
#  [1,
#   63,
#   1713,
#   236,
#   186,
#   10,
#   2,
#   1738,
#   2698,
#   144,
#   92,
#   73,
#   2544,
#   3538,
#   782,
#   2466,
#   17,
#   1127,
#   1515,
#   8252,
#   427,
#   7,
#   1,
#   63,
#   1713],
#  [18,
#   33,
#   257,
#   950,
#   825,
#   1944,
#   6641,
#   7,
#   331,
#   18,
#   33,
#   257,
#   950,
#   825,
#   1944,
#   6641,
#   7,
#   331,
#   18,
#   33,
#   257,
#   950,
#   825,
#   1944,
#   6641],
#  [13310,
#   9779,
#   9780,
#   3749,
#   119,
#   3,
#   1,
#   977,
#   4387,
#   61,
#   524,
#   8,
#   808,
#   10006,
#   1207,
#   11807,
#   2777,
#   17,
#   209,
#   372,
#   98,
#   43,
#   172,
#   606,
#   14260],
#  [151,
#   677,
#   3521,
#   199,
#   370,
#   744,
#   19,
#   370,
#   1221,
#   2038,
#   39,
#   2839,
#   524,
#   8,
#   1869,
#   2228,
#   2038,
#   84,
#   3,
#   8291,
#   3,
#   209,
#   11,
#   395,
#   32],
#  [8,
#   43,
#   908,
#   23,
#   10907,
#   11,
#   744,
#   647,
#   153,
#   1197,
#   249,
#   1615,
#   500,
#   2617,
#   1769,
#   874,
#   11284,
#   242,
#   9543,
#   57,
#   8,
#   8202,
#   2038,
#   8,
#   1888],
#  [2408,
#   1274,
#   478,
#   293,
#   77,
#   10348,
#   3079,
#   282,
#   295,
#   2853,
#   10178,
#   13310,
#   18,
#   9857,
#   10,
#   1992,
#   19,
#   570,
#   1870,
#   566,
#   1865,
#   961,
#   1725,
#   39,
#   2408],
#  [8,
#   275,
#   157,
#   1202,
#   133,
#   350,
#   189,
#   8,
#   16,
#   393,
#   530,
#   3528,
#   606,
#   777,
#   18,
#   185,
#   1220,
#   51,
#   19,
#   12,
#   76,
#   11,
#   24,
#   10221,
#   133],
#  [578,
#   1101,
#   5,
#   758,
#   3749,
#   961,
#   2357,
#   8,
#   115,
#   5310,
#   5,
#   1,
#   494,
#   6,
#   60,
#   578,
#   1101,
#   5,
#   758,
#   3749,
#   961,
#   2357,
#   8,
#   115,
#   5310],
#  [183,
#   748,
#   207,
#   711,
#   6827,
#   73,
#   1921,
#   41,
#   183,
#   748,
#   207,
#   711,
#   6827,
#   73,
#   1921,
#   41,
#   183,
#   748,
#   207,
#   711,
#   6827,
#   73,
#   1921,
#   41,
#   183],
#  [263,
#   22,
#   3,
#   63,
#   711,
#   581,
#   10,
#   1327,
#   8640,
#   876,
#   569,
#   7,
#   1337,
#   454,
#   537,
#   1769,
#   36,
#   23,
#   229,
#   331,
#   263,
#   22,
#   3,
#   63,
#   711],
#  [3,
#   1829,
#   1233,
#   76,
#   360,
#   1854,
#   2112,
#   21,
#   3,
#   1829,
#   1233,
#   76,
#   360,
#   1854,
#   2112,
#   21,
#   3,
#   1829,
#   1233,
#   76,
#   360,
#   1854,
#   2112,
#   21,
#   3],
#  [11,
#   55,
#   81,
#   1,
#   643,
#   439,
#   45,
#   776,
#   20,
#   2574,
#   439,
#   2391,
#   776,
#   1,
#   27,
#   550,
#   1950,
#   107,
#   6,
#   678,
#   6,
#   7,
#   848,
#   213,
#   37],
#  [8,
#   1017,
#   482,
#   1242,
#   235,
#   10,
#   168,
#   87,
#   2973,
#   965,
#   6385,
#   245,
#   66,
#   67,
#   30,
#   41,
#   3752,
#   11991,
#   706,
#   5012,
#   8,
#   1017,
#   482,
#   1242,
#   235],
#  [13,
#   31,
#   3056,
#   233,
#   36,
#   538,
#   938,
#   132,
#   168,
#   84,
#   7767,
#   241,
#   136,
#   217,
#   17,
#   3794,
#   7,
#   1025,
#   13,
#   31,
#   3056,
#   233,
#   36,
#   538,
#   938],
#  [492,
#   90,
#   27,
#   24,
#   87,
#   77,
#   114,
#   34,
#   852,
#   12,
#   109,
#   3,
#   1062,
#   661,
#   12,
#   5664,
#   7,
#   1442,
#   492,
#   90,
#   27,
#   24,
#   87,
#   77,
#   114],
#  [4822,
#   3894,
#   1610,
#   301,
#   6183,
#   1912,
#   2012,
#   1973,
#   11155,
#   8989,
#   9009,
#   5264,
#   1200,
#   383,
#   159,
#   12789,
#   2668,
#   3187,
#   1,
#   760,
#   1548,
#   1603,
#   798,
#   49,
#   4],
#  [3,
#   39,
#   1275,
#   4920,
#   24,
#   759,
#   383,
#   159,
#   508,
#   1366,
#   115,
#   57,
#   209,
#   12917,
#   886,
#   759,
#   49,
#   383,
#   159,
#   44,
#   420,
#   6164,
#   79,
#   797,
#   49],
#  [12,
#   343,
#   3460,
#   1422,
#   5864,
#   1165,
#   180,
#   2204,
#   14,
#   303,
#   219,
#   1240,
#   2700,
#   596,
#   12,
#   343,
#   3460,
#   1422,
#   5864,
#   1165,
#   180,
#   2204,
#   14,
#   303,
#   219],
#  [65,
#   110,
#   19,
#   13,
#   24,
#   661,
#   5998,
#   12,
#   874,
#   780,
#   394,
#   4228,
#   21,
#   47,
#   1246,
#   65,
#   110,
#   19,
#   13,
#   24,
#   661,
#   5998,
#   12,
#   874,
#   780],
#  [3,
#   3688,
#   3523,
#   3,
#   11,
#   256,
#   3153,
#   1,
#   570,
#   1732,
#   3523,
#   5385,
#   2482,
#   69,
#   838,
#   7,
#   3,
#   3688,
#   3523,
#   3,
#   11,
#   256,
#   3153,
#   1,
#   570],
#  [3,
#   5104,
#   19,
#   5,
#   1028,
#   471,
#   5,
#   3521,
#   76,
#   69,
#   1697,
#   69,
#   1444,
#   5,
#   1298,
#   58,
#   5247,
#   21,
#   3,
#   5104,
#   19,
#   5,
#   1028,
#   471,
#   5],
#  [1494,
#   16,
#   997,
#   228,
#   5127,
#   53,
#   1,
#   68,
#   1118,
#   111,
#   831,
#   11829,
#   13325,
#   130,
#   578,
#   234,
#   17,
#   857,
#   17,
#   105,
#   52,
#   18,
#   129,
#   1,
#   17],
#  [86,
#   1593,
#   4639,
#   3403,
#   1707,
#   253,
#   2790,
#   2734,
#   213,
#   4,
#   2473,
#   212,
#   674,
#   7170,
#   694,
#   450,
#   869,
#   86,
#   1593,
#   4639,
#   3403,
#   1707,
#   253,
#   2790,
#   2734],
#  [1254,
#   260,
#   5984,
#   812,
#   2790,
#   321,
#   502,
#   151,
#   228,
#   12,
#   85,
#   655,
#   810,
#   1573,
#   2861,
#   213,
#   412,
#   463,
#   3139,
#   232,
#   2790,
#   52,
#   4030,
#   10,
#   19],
#  [86,
#   490,
#   13468,
#   831,
#   4461,
#   278,
#   88,
#   37,
#   78,
#   3963,
#   120,
#   79,
#   4646,
#   108,
#   1502,
#   37,
#   21,
#   86,
#   490,
#   13468,
#   831,
#   4461,
#   278,
#   88,
#   37],
#  [2166,
#   2,
#   16,
#   191,
#   9592,
#   127,
#   2200,
#   1128,
#   5774,
#   823,
#   60,
#   318,
#   210,
#   463,
#   3972,
#   2166,
#   2,
#   16,
#   191,
#   9592,
#   127,
#   2200,
#   1128,
#   5774,
#   823],
#  [8,
#   44,
#   11957,
#   58,
#   3776,
#   7079,
#   12,
#   782,
#   282,
#   295,
#   1,
#   241,
#   13,
#   25,
#   1,
#   782,
#   8,
#   202,
#   308,
#   295,
#   2938,
#   458,
#   1651,
#   350,
#   3854],
#  [12,
#   2641,
#   4383,
#   12,
#   363,
#   3,
#   495,
#   683,
#   24,
#   404,
#   102,
#   110,
#   3355,
#   696,
#   106,
#   110,
#   808,
#   808,
#   7,
#   132,
#   12,
#   2641,
#   4383,
#   12,
#   363],
#  [235,
#   241,
#   166,
#   1435,
#   158,
#   1208,
#   241,
#   1282,
#   528,
#   1,
#   4,
#   235,
#   241,
#   166,
#   1435,
#   158,
#   1208,
#   241,
#   1282,
#   528,
#   1,
#   4,
#   235,
#   241,
#   166],
#  [902,
#   23,
#   4744,
#   6158,
#   598,
#   84,
#   334,
#   48,
#   634,
#   41,
#   203,
#   160,
#   109,
#   25,
#   1,
#   784,
#   2484,
#   431,
#   6,
#   20,
#   53,
#   722,
#   15,
#   299,
#   858],
#  [7188,
#   867,
#   81,
#   1918,
#   954,
#   3038,
#   5003,
#   175,
#   10467,
#   111,
#   1040,
#   11506,
#   112,
#   6874,
#   496,
#   7,
#   101,
#   41,
#   7188,
#   867,
#   81,
#   1918,
#   954,
#   3038,
#   5003],
#  [7188,
#   867,
#   23,
#   3358,
#   11506,
#   199,
#   168,
#   25,
#   1,
#   860,
#   2,
#   73,
#   210,
#   7188,
#   867,
#   23,
#   3358,
#   11506,
#   199,
#   168,
#   25,
#   1,
#   860,
#   2,
#   73],
#  [8,
#   16,
#   7,
#   620,
#   99,
#   127,
#   177,
#   4108,
#   32,
#   10,
#   127,
#   295,
#   377,
#   24,
#   671,
#   209,
#   920,
#   1720,
#   66,
#   4108,
#   5,
#   1,
#   2057,
#   14051,
#   4108],
#  [3,
#   1183,
#   962,
#   386,
#   177,
#   5029,
#   4108,
#   2681,
#   1953,
#   4108,
#   1822,
#   174,
#   11,
#   4682,
#   17,
#   533,
#   200,
#   1130,
#   3535,
#   814,
#   387,
#   85,
#   21,
#   3,
#   1183],
#  [702,
#   209,
#   19,
#   2776,
#   532,
#   3171,
#   6165,
#   199,
#   5821,
#   2,
#   19,
#   209,
#   2776,
#   14,
#   4108,
#   65,
#   5287,
#   5821,
#   2,
#   4108,
#   97,
#   606,
#   1542,
#   4108,
#   17],
#  [5349,
#   473,
#   847,
#   4785,
#   151,
#   95,
#   1204,
#   7,
#   101,
#   41,
#   5349,
#   473,
#   847,
#   4785,
#   151,
#   95,
#   1204,
#   7,
#   101,
#   41,
#   5349,
#   473,
#   847,
#   4785,
#   151],
#  [18,
#   481,
#   172,
#   262,
#   165,
#   12533,
#   126,
#   8808,
#   3862,
#   5652,
#   1421,
#   175,
#   13,
#   65,
#   3,
#   16,
#   39,
#   740,
#   3790,
#   7,
#   2,
#   18,
#   481,
#   172,
#   262],
#  [172,
#   1,
#   1817,
#   181,
#   650,
#   146,
#   257,
#   2465,
#   11,
#   395,
#   303,
#   95,
#   181,
#   73,
#   734,
#   172,
#   1,
#   1817,
#   181,
#   650,
#   146,
#   257,
#   2465,
#   11,
#   395],
#  [89,
#   11,
#   832,
#   2483,
#   23,
#   1430,
#   11410,
#   522,
#   303,
#   12,
#   1430,
#   2767,
#   175,
#   7,
#   2,
#   89,
#   11,
#   832,
#   2483,
#   23,
#   1430,
#   11410,
#   522,
#   303,
#   12],
#  [10,
#   11,
#   19,
#   25,
#   1,
#   713,
#   5652,
#   175,
#   19,
#   795,
#   7,
#   2,
#   10,
#   11,
#   19,
#   25,
#   1,
#   713,
#   5652,
#   175,
#   19,
#   795,
#   7,
#   2,
#   10],
#  [3,
#   710,
#   115,
#   6199,
#   113,
#   6,
#   195,
#   117,
#   73,
#   317,
#   3,
#   710,
#   115,
#   6199,
#   113,
#   6,
#   195,
#   117,
#   73,
#   317,
#   3,
#   710,
#   115,
#   6199,
#   113],
#  [3,
#   297,
#   1778,
#   784,
#   5268,
#   405,
#   2477,
#   10,
#   541,
#   434,
#   23,
#   18,
#   10443,
#   51,
#   3071,
#   20,
#   238,
#   3,
#   91,
#   110,
#   587,
#   5268,
#   23,
#   10327,
#   18],
#  [226,
#   223,
#   4202,
#   1,
#   1970,
#   8,
#   11176,
#   507,
#   130,
#   234,
#   13,
#   28,
#   8,
#   1730,
#   8,
#   98,
#   227,
#   3151,
#   12418,
#   68,
#   53,
#   11,
#   8,
#   1122,
#   211],
#  [8,
#   941,
#   28,
#   2484,
#   8,
#   1082,
#   44,
#   466,
#   514,
#   1088,
#   547,
#   13639,
#   209,
#   2044,
#   645,
#   4861,
#   211,
#   8,
#   138,
#   19,
#   5,
#   336,
#   19,
#   5,
#   85],
#  [8,
#   26,
#   161,
#   13639,
#   404,
#   1822,
#   59,
#   899,
#   199,
#   256,
#   5,
#   8,
#   85,
#   240,
#   304,
#   1099,
#   21,
#   2,
#   8,
#   26,
#   161,
#   13639,
#   404,
#   1822,
#   59],
#  [2020,
#   3523,
#   404,
#   23,
#   8,
#   1183,
#   1539,
#   1092,
#   58,
#   2030,
#   7084,
#   405,
#   2477,
#   404,
#   249,
#   12696,
#   1402,
#   1689,
#   5,
#   7400,
#   13,
#   19,
#   3908,
#   2134,
#   342],
#  [1657,
#   1,
#   364,
#   1111,
#   2,
#   5189,
#   1941,
#   297,
#   3993,
#   1375,
#   10,
#   50,
#   2,
#   1,
#   42,
#   1111,
#   3392,
#   73,
#   210,
#   1657,
#   1,
#   364,
#   1111,
#   2,
#   5189],
#  [26,
#   57,
#   223,
#   88,
#   1771,
#   2878,
#   300,
#   4110,
#   2189,
#   1302,
#   97,
#   7,
#   343,
#   635,
#   31,
#   1,
#   133,
#   3045,
#   600,
#   4944,
#   977,
#   205,
#   1425,
#   26,
#   57],
#  [1425,
#   518,
#   1661,
#   549,
#   13,
#   216,
#   602,
#   809,
#   555,
#   44,
#   16,
#   360,
#   1434,
#   235,
#   1413,
#   130,
#   602,
#   809,
#   555,
#   1896,
#   361,
#   548,
#   8819,
#   1425,
#   518],
#  [8,
#   589,
#   53,
#   1,
#   364,
#   3,
#   364,
#   1023,
#   53,
#   10,
#   15,
#   117,
#   5,
#   288,
#   3,
#   8,
#   589,
#   2839,
#   2680,
#   133,
#   1,
#   1553,
#   4,
#   8,
#   589],
#  [1556,
#   84,
#   105,
#   241,
#   142,
#   394,
#   115,
#   21,
#   1556,
#   84,
#   105,
#   241,
#   142,
#   394,
#   115,
#   21,
#   1556,
#   84,
#   105,
#   241,
#   142,
#   394,
#   115,
#   21,
#   1556],
#  [3,
#   68,
#   53,
#   262,
#   1160,
#   5823,
#   8587,
#   2738,
#   5,
#   16,
#   1015,
#   1920,
#   61,
#   168,
#   86,
#   175,
#   30,
#   256,
#   54,
#   1950,
#   2473,
#   13456,
#   4127,
#   2729,
#   76],
#  [2729,
#   1,
#   532,
#   463,
#   2672,
#   2817,
#   1430,
#   15,
#   175,
#   962,
#   645,
#   412,
#   791,
#   108,
#   7,
#   1,
#   26,
#   1207,
#   13738,
#   2738,
#   60,
#   2729,
#   1,
#   532,
#   463],
#  [26,
#   61,
#   168,
#   605,
#   175,
#   1,
#   5547,
#   570,
#   143,
#   143,
#   3862,
#   8971,
#   143,
#   1360,
#   42,
#   251,
#   26,
#   61,
#   168,
#   605,
#   175,
#   1,
#   5547,
#   570,
#   143],
#  [58,
#   249,
#   19,
#   3,
#   1597,
#   22,
#   14,
#   2899,
#   606,
#   1,
#   122,
#   1367,
#   27,
#   45,
#   19,
#   19,
#   1156,
#   26,
#   400,
#   43,
#   2729,
#   58,
#   249,
#   19,
#   3],
#  [1888,
#   1391,
#   2738,
#   202,
#   1358,
#   610,
#   4002,
#   73,
#   5488,
#   2487,
#   1888,
#   1391,
#   2738,
#   202,
#   1358,
#   610,
#   4002,
#   73,
#   5488,
#   2487,
#   1888,
#   1391,
#   2738,
#   202,
#   1358],
#  [10541,
#   4429,
#   5,
#   13857,
#   1134,
#   1367,
#   2312,
#   2049,
#   124,
#   10541,
#   4429,
#   5,
#   13857,
#   1134,
#   1367,
#   2312,
#   2049,
#   124,
#   10541,
#   4429,
#   5,
#   13857,
#   1134,
#   1367,
#   2312],
#  [12,
#   77,
#   166,
#   2653,
#   4815,
#   73,
#   12,
#   77,
#   166,
#   2653,
#   4815,
#   73,
#   12,
#   77,
#   166,
#   2653,
#   4815,
#   73,
#   12,
#   77,
#   166,
#   2653,
#   4815,
#   73,
#   12],
#  [1215,
#   368,
#   353,
#   135,
#   185,
#   3389,
#   108,
#   1526,
#   54,
#   932,
#   1495,
#   4,
#   13598,
#   309,
#   1827,
#   233,
#   310,
#   977,
#   82,
#   1604,
#   496,
#   1215,
#   368,
#   353,
#   135],
#  [8,
#   313,
#   19,
#   240,
#   277,
#   11315,
#   51,
#   1423,
#   18,
#   8768,
#   21,
#   1723,
#   480,
#   1384,
#   1750,
#   41,
#   235,
#   8,
#   313,
#   19,
#   240,
#   277,
#   11315,
#   51,
#   1423],
#  [1136,
#   1,
#   2952,
#   4763,
#   168,
#   104,
#   1430,
#   305,
#   129,
#   29,
#   35,
#   1582,
#   1013,
#   1136,
#   1,
#   2952,
#   4763,
#   168,
#   104,
#   1430,
#   305,
#   129,
#   29,
#   35,
#   1582],
#  [22,
#   233,
#   13386,
#   349,
#   63,
#   319,
#   84,
#   2284,
#   1692,
#   221,
#   764,
#   223,
#   7307,
#   4,
#   1232,
#   4639,
#   8201,
#   22,
#   233,
#   13386,
#   349,
#   63,
#   319,
#   84,
#   2284],
#  [3,
#   147,
#   962,
#   872,
#   142,
#   320,
#   3628,
#   1699,
#   501,
#   7155,
#   3,
#   147,
#   962,
#   872,
#   142,
#   320,
#   3628,
#   1699,
#   501,
#   7155,
#   3,
#   147,
#   962,
#   872,
#   142],
#  [51,
#   1510,
#   387,
#   12373,
#   105,
#   3,
#   3356,
#   3,
#   16,
#   1563,
#   228,
#   24,
#   495,
#   4,
#   51,
#   1510,
#   387,
#   12373,
#   105,
#   3,
#   3356,
#   3,
#   16,
#   1563,
#   228],
#  [58,
#   184,
#   100,
#   531,
#   8,
#   345,
#   171,
#   8,
#   630,
#   138,
#   8,
#   63,
#   2076,
#   13,
#   1609,
#   260,
#   6,
#   8,
#   5073,
#   950,
#   1190,
#   250,
#   10265,
#   2132,
#   2330],
#  [16,
#   1045,
#   14,
#   261,
#   3539,
#   195,
#   8,
#   5419,
#   5022,
#   11601,
#   163,
#   8,
#   156,
#   1,
#   11,
#   22,
#   1985,
#   3684,
#   469,
#   13458,
#   469,
#   5369,
#   2132,
#   89,
#   313],
#  [15,
#   84,
#   9095,
#   1878,
#   801,
#   1462,
#   184,
#   478,
#   42,
#   2,
#   86,
#   363,
#   13,
#   1369,
#   11121,
#   51,
#   471,
#   77,
#   13332,
#   531,
#   124,
#   1695,
#   61,
#   315,
#   628],
#  [72,
#   32,
#   8,
#   72,
#   57,
#   98,
#   34,
#   1080,
#   5986,
#   8252,
#   13456,
#   382,
#   931,
#   407,
#   16,
#   1,
#   8,
#   250,
#   370,
#   69,
#   114,
#   14100,
#   1763,
#   26,
#   257],
#  [3,
#   20,
#   276,
#   7501,
#   15,
#   58,
#   2,
#   124,
#   1367,
#   23,
#   12,
#   2758,
#   12178,
#   68,
#   53,
#   533,
#   22,
#   3,
#   8818,
#   3,
#   155,
#   105,
#   297,
#   2753,
#   6410],
#  [217,
#   13707,
#   1756,
#   4982,
#   5,
#   822,
#   119,
#   7827,
#   3958,
#   4165,
#   889,
#   323,
#   1202,
#   1469,
#   44,
#   3672,
#   2,
#   100,
#   310,
#   215,
#   1919,
#   6948,
#   320,
#   1160,
#   1017],
#  [1,
#   368,
#   257,
#   76,
#   4983,
#   345,
#   171,
#   206,
#   6930,
#   5039,
#   1,
#   368,
#   257,
#   76,
#   4983,
#   345,
#   171,
#   206,
#   6930,
#   5039,
#   1,
#   368,
#   257,
#   76,
#   4983],
#  [3,
#   1174,
#   10,
#   359,
#   3,
#   369,
#   11,
#   51,
#   645,
#   2237,
#   165,
#   4,
#   37,
#   2946,
#   3,
#   1174,
#   10,
#   359,
#   3,
#   369,
#   11,
#   51,
#   645,
#   2237,
#   165],
#  [77,
#   8,
#   3993,
#   15,
#   216,
#   552,
#   1,
#   12,
#   21,
#   2,
#   77,
#   8,
#   3993,
#   15,
#   216,
#   552,
#   1,
#   12,
#   21,
#   2,
#   77,
#   8,
#   3993,
#   15,
#   216],
#  [105,
#   1317,
#   1621,
#   176,
#   98,
#   5394,
#   145,
#   140,
#   879,
#   50,
#   390,
#   18,
#   1824,
#   167,
#   1367,
#   140,
#   320,
#   182,
#   26,
#   1,
#   127,
#   33,
#   3449,
#   578,
#   4547],
#  [1905,
#   114,
#   57,
#   209,
#   4646,
#   2208,
#   514,
#   126,
#   115,
#   530,
#   4498,
#   169,
#   1310,
#   84,
#   242,
#   551,
#   11,
#   843,
#   159,
#   433,
#   126,
#   84,
#   27,
#   159,
#   126],
#  [2438,
#   52,
#   15,
#   389,
#   359,
#   2649,
#   3037,
#   5,
#   13385,
#   3582,
#   6,
#   1892,
#   49,
#   515,
#   1807,
#   1326,
#   966,
#   11,
#   122,
#   10,
#   40,
#   3139,
#   243,
#   3239,
#   359],
#  [469,
#   295,
#   238,
#   346,
#   1787,
#   51,
#   83,
#   67,
#   430,
#   22,
#   1039,
#   2,
#   891,
#   9851,
#   1357,
#   6326,
#   2847,
#   270,
#   60,
#   107,
#   183,
#   2903,
#   66,
#   67,
#   3506],
#  [90,
#   267,
#   432,
#   671,
#   209,
#   7964,
#   1987,
#   781,
#   3239,
#   125,
#   476,
#   86,
#   165,
#   3470,
#   1214,
#   8253,
#   2209,
#   2505,
#   4,
#   2,
#   90,
#   267,
#   432,
#   671,
#   209],
#  [3,
#   2967,
#   1207,
#   570,
#   1046,
#   570,
#   2769,
#   216,
#   1049,
#   11,
#   252,
#   77,
#   360,
#   7,
#   3,
#   2967,
#   1207,
#   570,
#   1046,
#   570,
#   2769,
#   216,
#   1049,
#   11,
#   252],
#  [3,
#   25,
#   1161,
#   1768,
#   1288,
#   908,
#   266,
#   295,
#   372,
#   4,
#   3,
#   25,
#   1161,
#   1768,
#   1288,
#   908,
#   266,
#   295,
#   372,
#   4,
#   3,
#   25,
#   1161,
#   1768,
#   1288],
#  [13,
#   1351,
#   648,
#   879,
#   144,
#   273,
#   84,
#   765,
#   691,
#   1224,
#   787,
#   1314,
#   1878,
#   691,
#   1224,
#   787,
#   685,
#   152,
#   214,
#   897,
#   51,
#   160,
#   765,
#   1224,
#   787],
#  [3,
#   613,
#   2,
#   397,
#   975,
#   424,
#   150,
#   526,
#   1,
#   7,
#   161,
#   3053,
#   218,
#   2617,
#   7,
#   101,
#   41,
#   3,
#   613,
#   2,
#   397,
#   975,
#   424,
#   150,
#   526],
#  [478,
#   1306,
#   293,
#   359,
#   530,
#   4644,
#   2310,
#   411,
#   1230,
#   10928,
#   3,
#   1649,
#   18,
#   379,
#   711,
#   790,
#   109,
#   4,
#   885,
#   478,
#   1306,
#   293,
#   359,
#   530,
#   4644],
#  [16,
#   191,
#   263,
#   22,
#   3,
#   3822,
#   466,
#   10,
#   228,
#   227,
#   647,
#   5029,
#   1,
#   364,
#   210,
#   106,
#   7410,
#   1199,
#   3,
#   797,
#   18,
#   24,
#   4,
#   149,
#   885],
#  [233,
#   1,
#   816,
#   3810,
#   31,
#   384,
#   496,
#   3909,
#   1276,
#   390,
#   1,
#   14344,
#   1620,
#   5,
#   1847,
#   496,
#   2484,
#   10286,
#   12715,
#   13626,
#   196,
#   1509,
#   104,
#   29,
#   35],
#  [249,
#   31,
#   296,
#   8,
#   1280,
#   305,
#   8,
#   17,
#   63,
#   263,
#   22,
#   3,
#   63,
#   711,
#   581,
#   1327,
#   8640,
#   18,
#   569,
#   21,
#   1337,
#   256,
#   249,
#   31,
#   296],
#  [473,
#   48,
#   159,
#   3523,
#   404,
#   1,
#   42,
#   1451,
#   587,
#   706,
#   5268,
#   3,
#   1,
#   257,
#   10,
#   12,
#   621,
#   1099,
#   21,
#   309,
#   318,
#   472,
#   473,
#   48,
#   159],
#  [524,
#   12,
#   1483,
#   12237,
#   2471,
#   42,
#   19,
#   1373,
#   8009,
#   370,
#   145,
#   16,
#   202,
#   1409,
#   12,
#   195,
#   458,
#   997,
#   1973,
#   19,
#   2412,
#   3,
#   1349,
#   1151,
#   79],
#  [86,
#   11994,
#   2,
#   4792,
#   4278,
#   2,
#   2776,
#   1121,
#   172,
#   14260,
#   20,
#   122,
#   98,
#   77,
#   4108,
#   2217,
#   15,
#   4108,
#   333,
#   16,
#   9319,
#   174,
#   857,
#   4185,
#   7124],
#  [437,
#   681,
#   1001,
#   34,
#   371,
#   45,
#   397,
#   138,
#   89,
#   134,
#   1105,
#   17,
#   2700,
#   1045,
#   7179,
#   11829,
#   60,
#   1933,
#   7187,
#   1103,
#   437,
#   681,
#   1001,
#   34,
#   371],
#  [1354,
#   50,
#   3145,
#   7483,
#   252,
#   1277,
#   8,
#   58,
#   1478,
#   2,
#   958,
#   2909,
#   12,
#   1579,
#   2143,
#   256,
#   380,
#   294,
#   4594,
#   637,
#   1354,
#   50,
#   3145,
#   7483,
#   252],
#  [345,
#   171,
#   649,
#   1,
#   1983,
#   242,
#   265,
#   8,
#   363,
#   1,
#   262,
#   27,
#   15,
#   1,
#   525,
#   2191,
#   3787,
#   277,
#   68,
#   159,
#   27,
#   31,
#   133,
#   109,
#   319],
#  [8,
#   43,
#   3,
#   852,
#   172,
#   68,
#   27,
#   159,
#   159,
#   196,
#   1032,
#   2,
#   109,
#   1157,
#   159,
#   549,
#   1157,
#   562,
#   1032,
#   280,
#   3161,
#   852,
#   93,
#   2,
#   8],
#  [1,
#   760,
#   1580,
#   5665,
#   1110,
#   14361,
#   701,
#   7013,
#   1408,
#   477,
#   12385,
#   419,
#   49,
#   1079,
#   14,
#   747,
#   566,
#   277,
#   93,
#   1074,
#   1,
#   760,
#   1580,
#   5665,
#   1110],
#  [307,
#   12,
#   4240,
#   1647,
#   566,
#   66,
#   19,
#   174,
#   99,
#   927,
#   196,
#   832,
#   619,
#   264,
#   66,
#   927,
#   12067,
#   489,
#   22,
#   1332,
#   307,
#   12,
#   4240,
#   1647,
#   566],
#  [6,
#   13326,
#   2790,
#   15,
#   478,
#   28,
#   7437,
#   90,
#   1673,
#   18,
#   601,
#   344,
#   703,
#   4694,
#   6,
#   344,
#   19,
#   899,
#   4469,
#   5823,
#   6663,
#   841,
#   9972,
#   205,
#   14],
#  [161,
#   28,
#   1389,
#   1651,
#   2459,
#   7043,
#   2993,
#   135,
#   299,
#   1397,
#   2220,
#   12,
#   316,
#   7593,
#   61,
#   370,
#   4694,
#   3420,
#   1986,
#   1052,
#   143,
#   1516,
#   1484,
#   416,
#   212],
#  [649,
#   4797,
#   2778,
#   5,
#   212,
#   1725,
#   1,
#   503,
#   3756,
#   2238,
#   4,
#   17,
#   256,
#   309,
#   649,
#   4797,
#   2778,
#   5,
#   212,
#   1725,
#   1,
#   503,
#   3756,
#   2238,
#   4],
#  [1957,
#   313,
#   1587,
#   1408,
#   757,
#   2717,
#   343,
#   2175,
#   5931,
#   4352,
#   27,
#   37,
#   18,
#   124,
#   3460,
#   2621,
#   8,
#   438,
#   3460,
#   2621,
#   957,
#   3908,
#   776,
#   4757,
#   100],
#  [58,
#   184,
#   882,
#   122,
#   55,
#   1615,
#   13030,
#   3314,
#   379,
#   3,
#   10409,
#   7544,
#   390,
#   4198,
#   5840,
#   5,
#   16,
#   1776,
#   90,
#   19,
#   2037,
#   747,
#   5,
#   68,
#   396],
#  [207,
#   740,
#   232,
#   783,
#   1,
#   2,
#   1569,
#   6,
#   7,
#   2,
#   207,
#   740,
#   232,
#   783,
#   1,
#   2,
#   1569,
#   6,
#   7,
#   2,
#   207,
#   740,
#   232,
#   783,
#   1],
#  [3,
#   6763,
#   11,
#   1255,
#   5,
#   91,
#   13,
#   1040,
#   18,
#   703,
#   12,
#   1136,
#   7,
#   3,
#   6763,
#   11,
#   1255,
#   5,
#   91,
#   13,
#   1040,
#   18,
#   703,
#   12,
#   1136],
#  [9335,
#   288,
#   5344,
#   478,
#   14,
#   208,
#   2331,
#   91,
#   122,
#   5285,
#   226,
#   3960,
#   411,
#   125,
#   4094,
#   1283,
#   4,
#   1361,
#   1384,
#   2621,
#   813,
#   1142,
#   660,
#   454,
#   852],
#  [194,
#   194,
#   49,
#   2239,
#   342,
#   15,
#   389,
#   232,
#   12465,
#   5,
#   1,
#   1590,
#   50,
#   21,
#   4672,
#   125,
#   194,
#   194,
#   49,
#   2239,
#   342,
#   15,
#   389,
#   232,
#   12465],
#  [199,
#   1,
#   10,
#   386,
#   54,
#   49,
#   26,
#   2044,
#   3658,
#   718,
#   1728,
#   700,
#   3654,
#   149,
#   111,
#   23,
#   1869,
#   1,
#   758,
#   128,
#   6,
#   568,
#   39,
#   382,
#   15],
#  [1950,
#   286,
#   77,
#   780,
#   3265,
#   1431,
#   19,
#   77,
#   55,
#   846,
#   997,
#   42,
#   84,
#   4059,
#   3507,
#   192,
#   2321,
#   122,
#   411,
#   1647,
#   53,
#   7,
#   316,
#   514,
#   938],
#  [13,
#   111,
#   3,
#   710,
#   328,
#   196,
#   8527,
#   1650,
#   99,
#   196,
#   8527,
#   160,
#   158,
#   12,
#   1154,
#   410,
#   347,
#   4194,
#   1734,
#   706,
#   6332,
#   334,
#   7,
#   5679,
#   13],
#  [4039,
#   131,
#   889,
#   196,
#   8527,
#   1421,
#   175,
#   2166,
#   4139,
#   10917,
#   52,
#   3362,
#   2,
#   323,
#   7,
#   2678,
#   4039,
#   131,
#   889,
#   196,
#   8527,
#   1421,
#   175,
#   2166,
#   4139],
#  [3,
#   12426,
#   76,
#   1992,
#   1103,
#   495,
#   131,
#   6,
#   13862,
#   17,
#   495,
#   51,
#   4144,
#   2033,
#   22,
#   3,
#   180,
#   3165,
#   380,
#   380,
#   3,
#   1285,
#   1015,
#   107,
#   79],
#  [1364,
#   380,
#   380,
#   9271,
#   678,
#   7203,
#   678,
#   4889,
#   104,
#   368,
#   4960,
#   50,
#   194,
#   16,
#   89,
#   8,
#   1,
#   4889,
#   15,
#   21,
#   951,
#   1364,
#   380,
#   380,
#   9271],
#  [263,
#   22,
#   3,
#   63,
#   711,
#   581,
#   10,
#   12,
#   1327,
#   8640,
#   569,
#   18,
#   1982,
#   941,
#   556,
#   1401,
#   1337,
#   263,
#   22,
#   3,
#   63,
#   711,
#   581,
#   10,
#   12],
#  [3,
#   249,
#   31,
#   296,
#   8,
#   1280,
#   305,
#   17,
#   63,
#   60,
#   1337,
#   3,
#   249,
#   31,
#   296,
#   8,
#   1280,
#   305,
#   17,
#   63,
#   60,
#   1337,
#   3,
#   249,
#   31],
#  [129,
#   148,
#   226,
#   1036,
#   87,
#   683,
#   234,
#   22,
#   1,
#   610,
#   3854,
#   2,
#   830,
#   366,
#   2417,
#   3725,
#   1652,
#   7,
#   101,
#   41,
#   129,
#   148,
#   226,
#   1036,
#   87],
#  [7032,
#   1354,
#   50,
#   9300,
#   39,
#   158,
#   3,
#   1372,
#   3859,
#   6,
#   69,
#   1023,
#   158,
#   365,
#   2537,
#   8,
#   26,
#   249,
#   6,
#   76,
#   7032,
#   1190,
#   3,
#   678,
#   420],
#  [559,
#   1140,
#   253,
#   70,
#   168,
#   1,
#   532,
#   163,
#   14,
#   55,
#   3,
#   10074,
#   2378,
#   745,
#   156,
#   1,
#   2609,
#   70,
#   6208,
#   276,
#   2378,
#   80,
#   315,
#   1629,
#   34],
#  [217,
#   2079,
#   122,
#   3694,
#   384,
#   2484,
#   538,
#   890,
#   130,
#   28,
#   222,
#   544,
#   82,
#   3334,
#   2335,
#   753,
#   1803,
#   12269,
#   7,
#   2261,
#   217,
#   2079,
#   122,
#   3694,
#   384],
#  [2426,
#   175,
#   4370,
#   19,
#   964,
#   1096,
#   83,
#   3258,
#   182,
#   559,
#   2004,
#   19,
#   11,
#   12,
#   63,
#   131,
#   66,
#   3258,
#   460,
#   4762,
#   409,
#   2426,
#   175,
#   4370,
#   19],
#  [57,
#   98,
#   82,
#   1118,
#   257,
#   266,
#   330,
#   207,
#   2222,
#   505,
#   7032,
#   47,
#   8589,
#   5,
#   252,
#   11,
#   82,
#   13,
#   2222,
#   1140,
#   8254,
#   70,
#   6412,
#   595,
#   2778],
#  [2303,
#   205,
#   113,
#   2334,
#   12,
#   1,
#   721,
#   13456,
#   22,
#   461,
#   958,
#   45,
#   1597,
#   13456,
#   378,
#   1377,
#   8916,
#   15,
#   12,
#   4657,
#   2,
#   378,
#   10727,
#   2,
#   1547],
#  [1082,
#   1045,
#   3155,
#   2303,
#   195,
#   1586,
#   11,
#   171,
#   1773,
#   10511,
#   957,
#   50,
#   357,
#   4418,
#   12916,
#   7184,
#   2533,
#   60,
#   329,
#   230,
#   1377,
#   564,
#   6168,
#   1082,
#   1045],
#  [1198,
#   3203,
#   1271,
#   1001,
#   19,
#   2315,
#   1488,
#   83,
#   19,
#   13697,
#   137,
#   3067,
#   120,
#   32,
#   212,
#   819,
#   3188,
#   158,
#   278,
#   923,
#   3743,
#   7575,
#   12358,
#   52,
#   15],
#  [4888,
#   1699,
#   949,
#   5,
#   835,
#   212,
#   1431,
#   795,
#   135,
#   500,
# ...
#   150,
#   148],
#  [221,
#   13,
#   28,
#   16,
#   1,
#   1804,
#   5595,
#   1313,
#   268,
#   61,
#   7,
#   210,
#   221,
#   13,
#   28,
#   16,
#   1,
#   1804,
#   5595,
#   1313,
#   268,
#   61,
#   7,
#   210,
#   221],
#  [10,
#   27,
#   146,
#   538,
#   23,
#   882,
#   12752,
#   1139,
#   111,
#   510,
#   69,
#   3986,
#   13583,
#   2010,
#   384,
#   5003,
#   10461,
#   273,
#   18,
#   179,
#   205,
#   10636,
#   1442,
#   10,
#   27],
#  [44,
#   1697,
#   554,
#   10221,
#   439,
#   1023,
#   912,
#   4054,
#   347,
#   970,
#   86,
#   10335,
#   69,
#   1859,
#   1444,
#   1731,
#   4988,
#   160,
#   5003,
#   2853,
#   36,
#   23,
#   538,
#   219,
#   1021],
#  [300,
#   538,
#   1646,
#   146,
#   1935,
#   2047,
#   520,
#   198,
#   232,
#   273,
#   541,
#   266,
#   9280,
#   1349,
#   302,
#   14000,
#   117,
#   198,
#   3334,
#   2010,
#   196,
#   273,
#   11270,
#   541,
#   266],
#  [3,
#   10409,
#   34,
#   390,
#   2119,
#   238,
#   119,
#   970,
#   308,
#   125,
#   3817,
#   2119,
#   7,
#   1655,
#   98,
#   18,
#   317,
#   1334,
#   2767,
#   2672,
#   1376,
#   26,
#   249,
#   6,
#   5353],
#  [52,
#   2331,
#   82,
#   538,
#   23,
#   4274,
#   200,
#   1396,
#   1633,
#   3334,
#   1798,
#   546,
#   1200,
#   1317,
#   189,
#   44,
#   423,
#   1146,
#   259,
#   22,
#   158,
#   160,
#   1383,
#   145,
#   694],
#  [835,
#   4696,
#   111,
#   2780,
#   158,
#   538,
#   23,
#   1221,
#   5,
#   135,
#   22,
#   3,
#   1185,
#   398,
#   5943,
#   39,
#   10,
#   13,
#   90,
#   1243,
#   90,
#   27,
#   58,
#   1870,
#   179],
#  [17,
#   8571,
#   1179,
#   5750,
#   3,
#   422,
#   3233,
#   17,
#   63,
#   511,
#   2984,
#   1,
#   1451,
#   8055,
#   97,
#   57,
#   119,
#   951,
#   1368,
#   4,
#   9637,
#   2210,
#   17,
#   8571,
#   1179],
#  [47,
#   247,
#   30,
#   3,
#   85,
#   3546,
#   281,
#   13651,
#   12,
#   1062,
#   79,
#   4861,
#   211,
#   4767,
#   222,
#   165,
#   788,
#   276,
#   3,
#   58,
#   5288,
#   247,
#   349,
#   500,
#   1],
#  [1140,
#   22,
#   506,
#   11,
#   2567,
#   14,
#   293,
#   2313,
#   1382,
#   894,
#   21,
#   1140,
#   22,
#   506,
#   11,
#   2567,
#   14,
#   293,
#   2313,
#   1382,
#   894,
#   21,
#   1140,
#   22,
#   506],
#  [1969,
#   104,
#   12582,
#   494,
#   969,
#   35,
#   4532,
#   2298,
#   768,
#   12,
#   115,
#   7,
#   876,
#   142,
#   256,
#   1969,
#   104,
#   12582,
#   494,
#   969,
#   35,
#   4532,
#   2298,
#   768,
#   12],
#  [3,
#   43,
#   1201,
#   502,
#   360,
#   159,
#   14272,
#   13550,
#   159,
#   5314,
#   195,
#   541,
#   13263,
#   2,
#   1137,
#   287,
#   258,
#   3,
#   43,
#   1201,
#   502,
#   360,
#   159,
#   14272,
#   13550],
#  [979,
#   3,
#   1,
#   413,
#   4944,
#   265,
#   120,
#   5,
#   777,
#   215,
#   1757,
#   480,
#   329,
#   230,
#   102,
#   137,
#   120,
#   229,
#   5381,
#   5,
#   950,
#   949,
#   4954,
#   979,
#   3],
#  [3,
#   670,
#   1674,
#   10,
#   481,
#   5,
#   554,
#   1916,
#   115,
#   1446,
#   154,
#   607,
#   200,
#   5844,
#   2693,
#   189,
#   5,
#   44,
#   968,
#   92,
#   7,
#   5381,
#   3,
#   670,
#   1674],
#  [8,
#   2526,
#   18,
#   504,
#   5,
#   14057,
#   328,
#   154,
#   947,
#   81,
#   10,
#   187,
#   154,
#   315,
#   1916,
#   25,
#   1,
#   919,
#   1452,
#   7,
#   5381,
#   8,
#   2526,
#   18,
#   504],
#  [12727,
#   632,
#   142,
#   694,
#   3188,
#   1488,
#   181,
#   81,
#   3,
#   5367,
#   173,
#   1485,
#   494,
#   2361,
#   12727,
#   632,
#   142,
#   694,
#   3188,
#   1488,
#   181,
#   81,
#   3,
#   5367,
#   173],
#  [256,
#   1021,
#   1998,
#   23,
#   1169,
#   3268,
#   404,
#   102,
#   84,
#   56,
#   627,
#   6772,
#   4821,
#   2552,
#   158,
#   256,
#   1021,
#   1998,
#   23,
#   1169,
#   3268,
#   404,
#   102,
#   84,
#   56],
#  [54,
#   4074,
#   638,
#   12,
#   400,
#   962,
#   13,
#   934,
#   3,
#   1062,
#   882,
#   471,
#   7,
#   54,
#   4074,
#   638,
#   12,
#   400,
#   962,
#   13,
#   934,
#   3,
#   1062,
#   882,
#   471],
#  [320,
#   78,
#   1583,
#   4523,
#   38,
#   123,
#   417,
#   1679,
#   7112,
#   619,
#   434,
#   100,
#   520,
#   1977,
#   86,
#   2900,
#   166,
#   22,
#   1379,
#   2624,
#   31,
#   7351,
#   170,
#   617,
#   958],
#  [793,
#   429,
#   6,
#   218,
#   558,
#   2064,
#   580,
#   6427,
#   90,
#   1530,
#   173,
#   1041,
#   2,
#   177,
#   879,
#   1106,
#   183,
#   14,
#   1102,
#   13,
#   217,
#   2,
#   30,
#   1102,
#   1530],
#  [10,
#   762,
#   217,
#   158,
#   1106,
#   177,
#   2224,
#   1651,
#   2825,
#   6873,
#   743,
#   2614,
#   509,
#   1914,
#   558,
#   627,
#   35,
#   10,
#   762,
#   217,
#   158,
#   1106,
#   177,
#   2224,
#   1651],
#  [108,
#   1,
#   252,
#   321,
#   6952,
#   18,
#   70,
#   4917,
#   1400,
#   12730,
#   1497,
#   95,
#   5016,
#   60,
#   124,
#   9906,
#   108,
#   1,
#   252,
#   321,
#   6952,
#   18,
#   70,
#   4917,
#   1400],
#  [55,
#   643,
#   211,
#   2734,
#   1092,
#   5337,
#   2379,
#   1424,
#   166,
#   694,
#   21,
#   715,
#   4989,
#   55,
#   643,
#   211,
#   2734,
#   1092,
#   5337,
#   2379,
#   1424,
#   166,
#   694,
#   21,
#   715],
#  [94,
#   1543,
#   1,
#   1314,
#   316,
#   2375,
#   499,
#   13094,
#   491,
#   925,
#   2307,
#   61,
#   206,
#   5762,
#   9899,
#   94,
#   1543,
#   1,
#   1314,
#   316,
#   2375,
#   499,
#   13094,
#   491,
#   925],
#  [140,
#   180,
#   1341,
#   169,
#   231,
#   4849,
#   3530,
#   948,
#   303,
#   282,
#   948,
#   2092,
#   1109,
#   69,
#   231,
#   1,
#   1250,
#   29,
#   612,
#   140,
#   180,
#   1341,
#   169,
#   231,
#   4849],
#  [142,
#   1,
#   932,
#   694,
#   5135,
#   453,
#   110,
#   178,
#   2531,
#   17,
#   110,
#   1,
#   5135,
#   2324,
#   453,
#   505,
#   5,
#   68,
#   1313,
#   159,
#   224,
#   53,
#   1092,
#   178,
#   1950],
#  [1378,
#   10442,
#   10416,
#   8,
#   151,
#   348,
#   17,
#   8,
#   240,
#   10416,
#   245,
#   8,
#   370,
#   5034,
#   793,
#   5,
#   25,
#   1,
#   1,
#   717,
#   206,
#   13815,
#   1378,
#   10442,
#   10416],
#  [614,
#   196,
#   547,
#   1,
#   14,
#   145,
#   28,
#   247,
#   29,
#   464,
#   614,
#   196,
#   547,
#   1,
#   14,
#   145,
#   28,
#   247,
#   29,
#   464,
#   614,
#   196,
#   547,
#   1,
#   14],
#  [9857,
#   1807,
#   5,
#   2176,
#   26,
#   51,
#   10272,
#   696,
#   106,
#   968,
#   4845,
#   382,
#   1689,
#   982,
#   808,
#   140,
#   702,
#   13,
#   12185,
#   80,
#   2834,
#   2378,
#   1215,
#   49,
#   29],
#  [90,
#   416,
#   842,
#   154,
#   32,
#   328,
#   176,
#   512,
#   1050,
#   306,
#   1765,
#   337,
#   574,
#   12054,
#   837,
#   386,
#   337,
#   113,
#   29,
#   35,
#   90,
#   416,
#   842,
#   154,
#   32],
#  [58,
#   2030,
#   91,
#   20,
#   2875,
#   8,
#   117,
#   406,
#   113,
#   3354,
#   4065,
#   58,
#   2030,
#   91,
#   20,
#   2875,
#   8,
#   117,
#   406,
#   113,
#   3354,
#   4065,
#   58,
#   2030,
#   91],
#  [172,
#   363,
#   1111,
#   58,
#   8094,
#   19,
#   93,
#   7150,
#   8811,
#   153,
#   172,
#   363,
#   1111,
#   58,
#   8094,
#   19,
#   93,
#   7150,
#   8811,
#   153,
#   172,
#   363,
#   1111,
#   58,
#   8094],
#  [1122,
#   1,
#   254,
#   1143,
#   2168,
#   6,
#   568,
#   1233,
#   19,
#   2863,
#   452,
#   78,
#   452,
#   14196,
#   356,
#   530,
#   10,
#   99,
#   5595,
#   1747,
#   2393,
#   19,
#   2,
#   30,
#   14196],
#  [3,
#   58,
#   1478,
#   2,
#   1235,
#   230,
#   3,
#   846,
#   13,
#   230,
#   91,
#   370,
#   90,
#   109,
#   216,
#   4,
#   3024,
#   6919,
#   3,
#   58,
#   1478,
#   2,
#   1235,
#   230,
#   3],
#  [8725,
#   8,
#   43,
#   52,
#   1312,
#   609,
#   651,
#   8,
#   181,
#   3509,
#   10671,
#   7,
#   2,
#   8725,
#   8,
#   43,
#   52,
#   1312,
#   609,
#   651,
#   8,
#   181,
#   3509,
#   10671,
#   7],
#  [1371,
#   1413,
#   13,
#   6,
#   996,
#   348,
#   7,
#   4292,
#   1371,
#   1413,
#   13,
#   6,
#   996,
#   348,
#   7,
#   4292,
#   1371,
#   1413,
#   13,
#   6,
#   996,
#   348,
#   7,
#   4292,
#   1371],
#  [2870,
#   2094,
#   346,
#   823,
#   399,
#   1932,
#   16,
#   491,
#   1307,
#   29,
#   1336,
#   220,
#   2870,
#   2094,
#   346,
#   823,
#   399,
#   1932,
#   16,
#   491,
#   1307,
#   29,
#   1336,
#   220,
#   2870],
#  [660,
#   124,
#   2160,
#   42,
#   28,
#   204,
#   741,
#   31,
#   555,
#   164,
#   602,
#   555,
#   109,
#   5839,
#   851,
#   1264,
#   1468,
#   11196,
#   7,
#   3552,
#   265,
#   88,
#   153,
#   660,
#   124],
#  [410,
#   655,
#   79,
#   6,
#   69,
#   7,
#   47,
#   251,
#   2830,
#   52,
#   3781,
#   643,
#   107,
#   4842,
#   410,
#   655,
#   79,
#   6,
#   69,
#   7,
#   47,
#   251,
#   2830,
#   52,
#   3781],
#  [8,
#   2308,
#   1730,
#   195,
#   3034,
#   122,
#   6706,
#   13753,
#   342,
#   7860,
#   20,
#   341,
#   1103,
#   60,
#   149,
#   2621,
#   2037,
#   10940,
#   8,
#   2308,
#   1730,
#   195,
#   3034,
#   122,
#   6706],
#  [8,
#   58,
#   1802,
#   76,
#   2,
#   473,
#   1701,
#   14,
#   32,
#   70,
#   8,
#   58,
#   1802,
#   2,
#   58,
#   1912,
#   1657,
#   370,
#   14,
#   2254,
#   2277,
#   60,
#   10940,
#   8,
#   58],
#  [5700,
#   1,
#   58,
#   3324,
#   8,
#   12470,
#   613,
#   3,
#   11,
#   1482,
#   642,
#   6639,
#   6493,
#   8,
#   1,
#   2487,
#   840,
#   8,
#   1802,
#   699,
#   1371,
#   2406,
#   8,
#   20,
#   4833],
#  [174,
#   1606,
#   453,
#   812,
#   1657,
#   1,
#   12565,
#   5247,
#   1401,
#   9444,
#   174,
#   1606,
#   453,
#   812,
#   1657,
#   1,
#   12565,
#   5247,
#   1401,
#   9444,
#   174,
#   1606,
#   453,
#   812,
#   1657],
#  [1292,
#   1383,
#   384,
#   609,
#   1452,
#   398,
#   1493,
#   1617,
#   31,
#   5,
#   635,
#   273,
#   72,
#   1246,
#   18,
#   825,
#   592,
#   597,
#   902,
#   1246,
#   1292,
#   1383,
#   384,
#   609,
#   1452],
#  [308,
#   6931,
#   334,
#   118,
#   462,
#   519,
#   32,
#   81,
#   8968,
#   643,
#   372,
#   402,
#   965,
#   166,
#   2343,
#   440,
#   78,
#   6386,
#   531,
#   6,
#   6,
#   1,
#   1217,
#   248,
#   213],
#  [1629,
#   34,
#   471,
#   57,
#   2,
#   1866,
#   4694,
#   387,
#   151,
#   228,
#   4504,
#   2,
#   16,
#   685,
#   3,
#   679,
#   45,
#   71,
#   2,
#   276,
#   7,
#   324,
#   304,
#   14,
#   80],
#  [79,
#   116,
#   3,
#   1,
#   257,
#   3,
#   151,
#   862,
#   1,
#   469,
#   195,
#   400,
#   2352,
#   13,
#   80,
#   8,
#   15,
#   1752,
#   191,
#   195,
#   8,
#   180,
#   80,
#   1286,
#   2488],
#  [2207,
#   1891,
#   34,
#   1219,
#   1552,
#   6543,
#   11,
#   207,
#   1006,
#   2207,
#   1680,
#   390,
#   778,
#   253,
#   19,
#   12,
#   5694,
#   3796,
#   1080,
#   1204,
#   34,
#   24,
#   12,
#   1522,
#   500],
#  [711,
#   646,
#   1,
#   26,
#   127,
#   1116,
#   126,
#   7,
#   6166,
#   192,
#   181,
#   647,
#   638,
#   711,
#   259,
#   4316,
#   2049,
#   616,
#   1649,
#   48,
#   6650,
#   711,
#   646,
#   1,
#   26],
#  [11,
#   726,
#   12836,
#   655,
#   426,
#   12,
#   3480,
#   15,
#   7985,
#   30,
#   798,
#   41,
#   5856,
#   746,
#   597,
#   103,
#   2521,
#   14232,
#   11,
#   726,
#   12836,
#   655,
#   426,
#   12,
#   3480],
#  [18,
#   2390,
#   1575,
#   2358,
#   71,
#   1385,
#   130,
#   2358,
#   1819,
#   277,
#   5,
#   398,
#   6,
#   6,
#   4147,
#   2763,
#   18,
#   2390,
#   1575,
#   2358,
#   71,
#   1385,
#   130,
#   2358,
#   1819],
#  [105,
#   2839,
#   39,
#   1351,
#   414,
#   1162,
#   292,
#   3641,
#   209,
#   28,
#   1646,
#   466,
#   813,
#   1162,
#   544,
#   7,
#   596,
#   6176,
#   105,
#   2839,
#   39,
#   1351,
#   414,
#   1162,
#   292],
#  [3,
#   929,
#   88,
#   27,
#   125,
#   159,
#   440,
#   2231,
#   355,
#   433,
#   440,
#   199,
#   11,
#   747,
#   2231,
#   355,
#   396,
#   282,
#   53,
#   16,
#   1,
#   952,
#   308,
#   5564,
#   440],
#  [20,
#   53,
#   3179,
#   241,
#   2179,
#   440,
#   3449,
#   1,
#   251,
#   2,
#   20,
#   53,
#   3179,
#   241,
#   2179,
#   440,
#   3449,
#   1,
#   251,
#   2,
#   20,
#   53,
#   3179,
#   241,
#   2179],
#  [1017,
#   8312,
#   360,
#   132,
#   459,
#   2494,
#   1506,
#   132,
#   562,
#   109,
#   734,
#   132,
#   899,
#   358,
#   694,
#   1468,
#   29,
#   1981,
#   2667,
#   1017,
#   8312,
#   360,
#   132,
#   459,
#   2494],
#  [1747,
#   36,
#   1991,
#   3666,
#   3220,
#   758,
#   14,
#   481,
#   54,
#   1469,
#   388,
#   1,
#   528,
#   2667,
#   6170,
#   37,
#   872,
#   220,
#   7,
#   2570,
#   1747,
#   36,
#   1991,
#   3666,
#   3220],
#  [8,
#   1,
#   155,
#   1734,
#   91,
#   360,
#   865,
#   1759,
#   390,
#   137,
#   88,
#   546,
#   1017,
#   132,
#   562,
#   109,
#   132,
#   899,
#   333,
#   580,
#   4,
#   2,
#   8,
#   1,
#   155],
#  [758,
#   125,
#   440,
#   1064,
#   418,
#   1679,
#   492,
#   187,
#   2667,
#   36,
#   81,
#   515,
#   398,
#   396,
#   1313,
#   114,
#   96,
#   1552,
#   899,
#   927,
#   9893,
#   672,
#   459,
#   2413,
#   2494],
#  [813,
#   84,
#   3501,
#   1299,
#   859,
#   7045,
#   84,
#   7761,
#   903,
#   4179,
#   383,
#   1558,
#   865,
#   1416,
#   1727,
#   6888,
#   1614,
#   2871,
#   7,
#   142,
#   255,
#   118,
#   235,
#   597,
#   902],
#  [12,
#   656,
#   5190,
#   813,
#   676,
#   813,
#   218,
#   93,
#   142,
#   12,
#   656,
#   5190,
#   813,
#   676,
#   813,
#   218,
#   93,
#   142,
#   12,
#   656,
#   5190,
#   813,
#   676,
#   813,
#   218],
#  [1114,
#   1109,
#   157,
#   2586,
#   1977,
#   52,
#   3078,
#   711,
#   889,
#   11148,
#   1689,
#   29,
#   213,
#   1114,
#   1109,
#   157,
#   2586,
#   1977,
#   52,
#   3078,
#   711,
#   889,
#   11148,
#   1689,
#   29],
#  [13457,
#   9387,
#   76,
#   18,
#   24,
#   12,
#   1056,
#   3,
#   1056,
#   8,
#   91,
#   360,
#   10,
#   161,
#   501,
#   3119,
#   18,
#   310,
#   5,
#   13,
#   3119,
#   501,
#   3520,
#   522,
#   2767],
#  [71,
#   31,
#   54,
#   1014,
#   10,
#   168,
#   1,
#   320,
#   11,
#   22,
#   20,
#   34,
#   143,
#   19,
#   2033,
#   286,
#   9246,
#   4674,
#   6424,
#   19,
#   350,
#   5878,
#   3588,
#   12,
#   145],
#  [3,
#   25,
#   368,
#   5239,
#   11,
#   126,
#   1,
#   849,
#   547,
#   18,
#   196,
#   1982,
#   5,
#   4203,
#   10461,
#   277,
#   11,
#   395,
#   5647,
#   3,
#   1776,
#   251,
#   585,
#   3389,
#   74],
#  [8,
#   151,
#   11,
#   1261,
#   100,
#   302,
#   8,
#   151,
#   1015,
#   34,
#   192,
#   11,
#   1,
#   1207,
#   536,
#   25,
#   364,
#   1405,
#   828,
#   6850,
#   398,
#   5878,
#   725,
#   65,
#   14],
#  [3,
#   172,
#   11,
#   1776,
#   8,
#   1181,
#   3,
#   115,
#   20,
#   1420,
#   1222,
#   228,
#   3,
#   123,
#   277,
#   10388,
#   148,
#   1374,
#   585,
#   3389,
#   3,
#   172,
#   11,
#   1776,
#   8],
#  [12,
#   916,
#   1178,
#   184,
#   3788,
#   654,
#   5,
#   1837,
#   838,
#   2244,
#   812,
#   64,
#   678,
#   644,
#   358,
#   269,
#   7203,
#   2778,
#   453,
#   812,
#   515,
#   29,
#   142,
#   12,
#   916],
#  [8,
#   2396,
#   8,
#   1518,
#   6,
#   8,
#   12277,
#   8,
#   4316,
#   8,
#   5314,
#   8,
#   1752,
#   11870,
#   20,
#   725,
#   192,
#   257,
#   5127,
#   494,
#   14272,
#   1218,
#   2319,
#   743,
#   2524],
#  [1747,
#   191,
#   13628,
#   500,
#   69,
#   711,
#   646,
#   23,
#   389,
#   6277,
#   1860,
#   258,
#   1084,
#   15,
#   45,
#   1224,
#   1,
#   1848,
#   1423,
#   500,
#   1747,
#   191,
#   13628,
#   500,
#   69],
#  [377,
#   2350,
#   1,
#   592,
#   1351,
#   174,
#   445,
#   152,
#   67,
#   7699,
#   258,
#   866,
#   3785,
#   23,
#   1462,
#   765,
#   29,
#   35,
#   2350,
#   377,
#   2350,
#   1,
#   592,
#   1351,
#   174],
#  [521,
#   414,
#   258,
#   1,
#   440,
#   360,
#   890,
#   2065,
#   345,
#   6,
#   518,
#   12,
#   1,
#   1016,
#   440,
#   582,
#   159,
#   440,
#   206,
#   4462,
#   47,
#   1496,
#   521,
#   414,
#   258],
#  [1860,
#   258,
#   3641,
#   6,
#   8,
#   6707,
#   2187,
#   4357,
#   671,
#   106,
#   16,
#   209,
#   3302,
#   345,
#   6,
#   4,
#   1747,
#   256,
#   37,
#   292,
#   3641,
#   450,
#   7165,
#   1860,
#   258],
#  [3,
#   1817,
#   2585,
#   1,
#   999,
#   18,
#   693,
#   18,
#   2068,
#   206,
#   318,
#   3089,
#   3,
#   1817,
#   2585,
#   1,
#   999,
#   18,
#   693,
#   18,
#   2068,
#   206,
#   318,
#   3089,
#   3],
#  [13,
#   4635,
#   1848,
#   8,
#   134,
#   1689,
#   3906,
#   1848,
#   2664,
#   683,
#   1533,
#   7,
#   13,
#   4635,
#   1848,
#   8,
#   134,
#   1689,
#   3906,
#   1848,
#   2664,
#   683,
#   1533,
#   7,
#   13],
#  [1,
#   2148,
#   1689,
#   19,
#   5,
#   43,
#   12,
#   91,
#   516,
#   12,
#   1327,
#   200,
#   12,
#   410,
#   14,
#   8320,
#   282,
#   580,
#   136,
#   217,
#   7,
#   1105,
#   2525,
#   1,
#   2148],
#  [849,
#   2006,
#   3899,
#   355,
#   280,
#   4025,
#   1361,
#   6,
#   68,
#   53,
#   2677,
#   3382,
#   983,
#   258,
#   182,
#   334,
#   6,
#   627,
#   1336,
#   849,
#   2006,
#   3899,
#   355,
#   280,
#   4025],
#  [805,
#   72,
#   5366,
#   247,
#   23,
#   3,
#   26,
#   478,
#   157,
#   1450,
#   1257,
#   10,
#   6262,
#   580,
#   478,
#   151,
#   20,
#   244,
#   5254,
#   12,
#   3979,
#   5142,
#   195,
#   1467,
#   5142],
#  [3,
#   1,
#   13,
#   276,
#   6826,
#   1503,
#   2805,
#   228,
#   537,
#   3304,
#   34,
#   276,
#   8,
#   1968,
#   55,
#   14,
#   1003,
#   3261,
#   8,
#   1354,
#   50,
#   1889,
#   7,
#   3,
#   1],
#  [1,
#   10986,
#   163,
#   3380,
#   1450,
#   15,
#   72,
#   399,
#   207,
#   161,
#   13,
#   1450,
#   172,
#   1298,
#   1852,
#   3684,
#   15,
#   134,
#   3272,
#   276,
#   10,
#   12,
#   8,
#   369,
#   2],
#  [3,
#   235,
#   10,
#   345,
#   309,
#   3026,
#   2771,
#   187,
#   1604,
#   24,
#   13281,
#   12402,
#   169,
#   5237,
#   89,
#   1,
#   173,
#   6844,
#   1620,
#   37,
#   4017,
#   6806,
#   1606,
#   2730,
#   82],
#  [1004,
#   14,
#   3306,
#   244,
#   4999,
#   85,
#   2325,
#   50,
#   1450,
#   1257,
#   775,
#   5543,
#   6157,
#   163,
#   828,
#   1133,
#   336,
#   4845,
#   138,
#   805,
#   2967,
#   121,
#   1549,
#   1514,
#   199],
#  [85,
#   2077,
#   140,
#   305,
#   713,
#   53,
#   13,
#   117,
#   515,
#   2694,
#   196,
#   440,
#   1112,
#   18,
#   5,
#   3,
#   76,
#   15,
#   80,
#   100,
#   26,
#   962,
#   36,
#   21,
#   85],
#  [35,
#   2423,
#   1946,
#   10873,
#   1486,
#   1225,
#   655,
#   979,
#   1486,
#   57,
#   1657,
#   209,
#   3092,
#   28,
#   460,
#   47,
#   75,
#   867,
#   2722,
#   35,
#   2423,
#   1946,
#   10873,
#   1486,
#   1225],
#  [86,
#   1217,
#   350,
#   2682,
#   10952,
#   573,
#   2720,
#   246,
#   3362,
#   2720,
#   246,
#   126,
#   6727,
#   362,
#   10166,
#   131,
#   1946,
#   4000,
#   26,
#   957,
#   158,
#   5,
#   1,
#   1079,
#   1089],
#  [16,
#   7,
#   3,
#   58,
#   1144,
#   3972,
#   765,
#   51,
#   1339,
#   389,
#   365,
#   355,
#   758,
#   508,
#   11,
#   11,
#   100,
#   5303,
#   359,
#   3432,
#   765,
#   1803,
#   3082,
#   48,
#   1876],
#  [3,
#   3785,
#   5,
#   25,
#   1330,
#   34,
#   253,
#   258,
#   3046,
#   1184,
#   288,
#   299,
#   15,
#   251,
#   2,
#   3,
#   3785,
#   5,
#   25,
#   1330,
#   34,
#   253,
#   258,
#   3046,
#   1184],
#  [1080,
#   100,
#   139,
#   1059,
#   23,
#   262,
#   497,
#   3033,
#   819,
#   1044,
#   1386,
#   4,
#   256,
#   798,
#   1071,
#   4162,
#   439,
#   23,
#   5760,
#   949,
#   124,
#   2914,
#   480,
#   472,
#   1080],
#  [535,
#   4316,
#   3,
#   3145,
#   240,
#   14,
#   22,
#   970,
#   10,
#   548,
#   6489,
#   428,
#   2,
#   504,
#   5,
#   4256,
#   28,
#   923,
#   1059,
#   23,
#   1,
#   1363,
#   497,
#   231,
#   1020],
#  [32,
#   4203,
#   4985,
#   215,
#   1126,
#   5,
#   5135,
#   159,
#   221,
#   1928,
#   11,
#   166,
#   73,
#   2914,
#   32,
#   4203,
#   4985,
#   215,
#   1126,
#   5,
#   5135,
#   159,
#   221,
#   1928,
#   11],
#  [350,
#   6616,
#   6489,
#   1017,
#   50,
#   10588,
#   5800,
#   3079,
#   1,
#   3335,
#   7,
#   785,
#   350,
#   6616,
#   6489,
#   1017,
#   50,
#   10588,
#   5800,
#   3079,
#   1,
#   3335,
#   7,
#   785,
#   350],
#  [3,
#   764,
#   2667,
#   36,
#   52,
#   3275,
#   11,
#   462,
#   220,
#   52,
#   5719,
#   32,
#   3,
#   57,
#   155,
#   1647,
#   10,
#   364,
#   12,
#   556,
#   7,
#   5273,
#   3,
#   764,
#   2667],
#  ...]

# %%
len(X_train)
# Out:
# 3893

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, LSTM, Dropout, Embedding, GaussianNoise
y = keras.utils.to_categorical(y_train, num_classes=3)
yt = keras.utils.to_categorical(y_test, num_classes=3)

# %%
vocab=len(wordnum)
del model
model = Sequential()
model.add(Embedding(vocab,output_dim=128))
model.add(LSTM(128, dropout=0.6, recurrent_dropout=0.3))
model.add(Dense(3, activation='sigmoid'))

#model.add(Dense(100,input_dim=3893))
#model.add(Dropout(0.4))
#model.add(Dense(3, activation='sigmoid'))


model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])
# Generate dummy data
import numpy as np

# Convert labels to categorical one-hot encoding

# %%
# Train the model, iterating on the data in batches of 32 samples
model.fit(X_train, y, epochs=50, batch_size=32, validation_split=0.1)
# Out:
# Train on 3503 samples, validate on 390 samples
# Epoch 1/50
# 3503/3503 [==============================] - 10s 3ms/step - loss: 1.0362 - acc: 0.4884 - val_loss: 1.0243 - val_acc: 0.4641
# Epoch 2/50
# 3503/3503 [==============================] - 7s 2ms/step - loss: 0.8634 - acc: 0.5998 - val_loss: 0.9975 - val_acc: 0.5308
# Epoch 3/50
# 3503/3503 [==============================] - 7s 2ms/step - loss: 0.7384 - acc: 0.6714 - val_loss: 1.0256 - val_acc: 0.5359
# Epoch 4/50
# 3503/3503 [==============================] - 7s 2ms/step - loss: 0.6480 - acc: 0.6934 - val_loss: 1.0554 - val_acc: 0.5256
# Epoch 5/50
# 3503/3503 [==============================] - 7s 2ms/step - loss: 0.5801 - acc: 0.7160 - val_loss: 1.0956 - val_acc: 0.5436
# Epoch 6/50
# 3503/3503 [==============================] - 7s 2ms/step - loss: 0.5441 - acc: 0.7528 - val_loss: 1.0559 - val_acc: 0.5641
# Epoch 7/50
# 3503/3503 [==============================] - 7s 2ms/step - loss: 0.4712 - acc: 0.8167 - val_loss: 1.1941 - val_acc: 0.6051
# Epoch 8/50
# 3503/3503 [==============================] - 7s 2ms/step - loss: 0.4025 - acc: 0.8564 - val_loss: 1.3601 - val_acc: 0.6103
# Epoch 9/50
# 3503/3503 [==============================] - 7s 2ms/step - loss: 0.3269 - acc: 0.8881 - val_loss: 1.3211 - val_acc: 0.6179
# Epoch 10/50
# 3503/3503 [==============================] - 7s 2ms/step - loss: 0.2852 - acc: 0.9104 - val_loss: 1.5575 - val_acc: 0.6154
# Epoch 11/50
# 3503/3503 [==============================] - 7s 2ms/step - loss: 0.2493 - acc: 0.9201 - val_loss: 1.4158 - val_acc: 0.6077
# Epoch 12/50
# 3503/3503 [==============================] - 7s 2ms/step - loss: 0.2065 - acc: 0.9398 - val_loss: 1.4862 - val_acc: 0.6103
# Epoch 13/50
# 3503/3503 [==============================] - 7s 2ms/step - loss: 0.1815 - acc: 0.9460 - val_loss: 1.5017 - val_acc: 0.5949
# Epoch 14/50
# 3503/3503 [==============================] - 7s 2ms/step - loss: 0.1480 - acc: 0.9540 - val_loss: 1.9348 - val_acc: 0.6128
# Epoch 15/50
# 3503/3503 [==============================] - 7s 2ms/step - loss: 0.1353 - acc: 0.9600 - val_loss: 1.8447 - val_acc: 0.6000
# Epoch 16/50
# 3503/3503 [==============================] - 7s 2ms/step - loss: 0.1249 - acc: 0.9646 - val_loss: 1.9285 - val_acc: 0.5974
# Epoch 17/50
# 3503/3503 [==============================] - 7s 2ms/step - loss: 0.1049 - acc: 0.9680 - val_loss: 2.1432 - val_acc: 0.6000
# Epoch 18/50
# 3503/3503 [==============================] - 7s 2ms/step - loss: 0.0925 - acc: 0.9729 - val_loss: 2.1349 - val_acc: 0.6026
# Epoch 19/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0818 - acc: 0.9746 - val_loss: 2.3053 - val_acc: 0.5872
# Epoch 20/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0717 - acc: 0.9789 - val_loss: 2.2394 - val_acc: 0.5974
# Epoch 21/50
# 3503/3503 [==============================] - 7s 2ms/step - loss: 0.0651 - acc: 0.9820 - val_loss: 2.2745 - val_acc: 0.5872
# Epoch 22/50
# 3503/3503 [==============================] - 7s 2ms/step - loss: 0.0689 - acc: 0.9797 - val_loss: 2.4026 - val_acc: 0.5821
# Epoch 23/50
# 3503/3503 [==============================] - 7s 2ms/step - loss: 0.0496 - acc: 0.9829 - val_loss: 2.5556 - val_acc: 0.6026
# Epoch 24/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0565 - acc: 0.9837 - val_loss: 2.5958 - val_acc: 0.5923
# Epoch 25/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0565 - acc: 0.9820 - val_loss: 2.5699 - val_acc: 0.5923
# Epoch 26/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0423 - acc: 0.9874 - val_loss: 2.6615 - val_acc: 0.6077
# Epoch 27/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0398 - acc: 0.9854 - val_loss: 2.6758 - val_acc: 0.6000
# Epoch 28/50
# 3503/3503 [==============================] - 7s 2ms/step - loss: 0.0326 - acc: 0.9877 - val_loss: 3.0964 - val_acc: 0.5949
# Epoch 29/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0409 - acc: 0.9877 - val_loss: 2.9152 - val_acc: 0.5974
# Epoch 30/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0344 - acc: 0.9894 - val_loss: 3.1875 - val_acc: 0.6000
# Epoch 31/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0360 - acc: 0.9897 - val_loss: 3.2883 - val_acc: 0.5769
# Epoch 32/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0343 - acc: 0.9883 - val_loss: 3.0422 - val_acc: 0.6000
# Epoch 33/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0242 - acc: 0.9929 - val_loss: 3.3495 - val_acc: 0.5897
# Epoch 34/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0292 - acc: 0.9906 - val_loss: 3.3536 - val_acc: 0.5744
# Epoch 35/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0266 - acc: 0.9917 - val_loss: 3.4668 - val_acc: 0.5974
# Epoch 36/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0236 - acc: 0.9917 - val_loss: 3.1526 - val_acc: 0.5795
# Epoch 37/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0294 - acc: 0.9909 - val_loss: 3.5154 - val_acc: 0.5667
# Epoch 38/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0241 - acc: 0.9920 - val_loss: 3.0746 - val_acc: 0.5897
# Epoch 39/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0232 - acc: 0.9926 - val_loss: 3.3529 - val_acc: 0.5718
# Epoch 40/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0152 - acc: 0.9931 - val_loss: 3.4676 - val_acc: 0.5821
# Epoch 41/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0196 - acc: 0.9920 - val_loss: 3.3297 - val_acc: 0.5872
# Epoch 42/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0171 - acc: 0.9920 - val_loss: 3.5670 - val_acc: 0.5846
# Epoch 43/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0208 - acc: 0.9934 - val_loss: 3.3596 - val_acc: 0.5872
# Epoch 44/50
# 3503/3503 [==============================] - 7s 2ms/step - loss: 0.0200 - acc: 0.9940 - val_loss: 3.4165 - val_acc: 0.5923
# Epoch 45/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0168 - acc: 0.9943 - val_loss: 3.7506 - val_acc: 0.5692
# Epoch 46/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0170 - acc: 0.9949 - val_loss: 3.5174 - val_acc: 0.5718
# Epoch 47/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0238 - acc: 0.9937 - val_loss: 3.5002 - val_acc: 0.5744
# Epoch 48/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0141 - acc: 0.9957 - val_loss: 3.6823 - val_acc: 0.5872
# Epoch 49/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0213 - acc: 0.9943 - val_loss: 3.6247 - val_acc: 0.5821
# Epoch 50/50
# 3503/3503 [==============================] - 8s 2ms/step - loss: 0.0139 - acc: 0.9954 - val_loss: 3.8769 - val_acc: 0.5846

# %%
model.evaluate(X_test, yt, batch_size=32)
# Out:
# 4573/4573 [==============================] - 3s 602us/step
# [2.5500021233695254, 0.57270938125450188]

# %%
del model

# %%
#tf-idf
from sklearn.feature_extraction.text import TfidfVectorizer
data_train = pd.read_pickle('data_train')
data_test = pd.read_pickle('data_test')

vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(data_train.loc[:,'text'])
X_test = vectorizer.transform(data_test.loc[:,'text'])
y_train, y_test = data_train['mood'], data_test['mood']
X_train, X_test
# Out:
# (<3893x14204 sparse matrix of type '<class 'numpy.float64'>'
#  	with 89815 stored elements in Compressed Sparse Row format>,
#  <4573x14204 sparse matrix of type '<class 'numpy.float64'>'
#  	with 103238 stored elements in Compressed Sparse Row format>)

# %%
# Преобразуем данные меток в тензоры
y = keras.utils.to_categorical(y_train, num_classes=3)
yt = keras.utils.to_categorical(y_test, num_classes=3)
print(y.shape, yt.shape)
# Out:
# (3893, 3) (4573, 3)

# %%
del model
model = Sequential()
model.add(Dense(100, activation='relu', input_dim=X_train.shape[1]))
model.add(Dropout(0.6))
model.add(GaussianNoise(1))
#model.add(Dense(100, activation='relu'))
#model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Generate dummy data

# Convert labels to categorical one-hot encoding


# Train the model, iterating on the data in batches of 32 samples
model.fit(X_train.toarray(), y, epochs=70, batch_size=32, validation_split = 0.1)
# Out:
# Train on 3503 samples, validate on 390 samples
# Epoch 1/70
# 3503/3503 [==============================] - 2s 531us/step - loss: 1.4858 - acc: 0.3571 - val_loss: 1.0776 - val_acc: 0.4000
# Epoch 2/70
# 3503/3503 [==============================] - 1s 326us/step - loss: 1.2811 - acc: 0.4017 - val_loss: 1.0693 - val_acc: 0.4000
# Epoch 3/70
# 3503/3503 [==============================] - 1s 335us/step - loss: 1.1418 - acc: 0.4416 - val_loss: 1.0659 - val_acc: 0.4000
# Epoch 4/70
# 3503/3503 [==============================] - 1s 327us/step - loss: 1.0632 - acc: 0.4710 - val_loss: 1.0487 - val_acc: 0.4205
# Epoch 5/70
# 3503/3503 [==============================] - 1s 328us/step - loss: 1.0077 - acc: 0.5050 - val_loss: 1.0427 - val_acc: 0.4256
# Epoch 6/70
# 3503/3503 [==============================] - 1s 335us/step - loss: 0.9719 - acc: 0.5355 - val_loss: 1.0262 - val_acc: 0.4410
# Epoch 7/70
# 3503/3503 [==============================] - 1s 326us/step - loss: 0.9451 - acc: 0.5498 - val_loss: 1.0138 - val_acc: 0.4538
# Epoch 8/70
# 3503/3503 [==============================] - 1s 326us/step - loss: 0.9168 - acc: 0.5801 - val_loss: 0.9914 - val_acc: 0.4872
# Epoch 9/70
# 3503/3503 [==============================] - 1s 325us/step - loss: 0.8860 - acc: 0.5943 - val_loss: 0.9737 - val_acc: 0.5179
# Epoch 10/70
# 3503/3503 [==============================] - 1s 325us/step - loss: 0.8528 - acc: 0.6123 - val_loss: 0.9561 - val_acc: 0.5359
# Epoch 11/70
# 3503/3503 [==============================] - 1s 333us/step - loss: 0.8349 - acc: 0.6223 - val_loss: 0.9379 - val_acc: 0.5462
# Epoch 12/70
# 3503/3503 [==============================] - 1s 335us/step - loss: 0.8001 - acc: 0.6389 - val_loss: 0.9225 - val_acc: 0.5487
# Epoch 13/70
# 3503/3503 [==============================] - 1s 326us/step - loss: 0.7823 - acc: 0.6512 - val_loss: 0.9145 - val_acc: 0.5615
# Epoch 14/70
# 3503/3503 [==============================] - 1s 333us/step - loss: 0.7527 - acc: 0.6666 - val_loss: 0.9230 - val_acc: 0.5513
# Epoch 15/70
# 3503/3503 [==============================] - 1s 334us/step - loss: 0.7213 - acc: 0.6891 - val_loss: 0.8997 - val_acc: 0.5692
# Epoch 16/70
# 3503/3503 [==============================] - 1s 335us/step - loss: 0.7352 - acc: 0.6663 - val_loss: 0.8949 - val_acc: 0.5718
# Epoch 17/70
# 3503/3503 [==============================] - 1s 342us/step - loss: 0.7244 - acc: 0.6846 - val_loss: 0.8860 - val_acc: 0.5769
# Epoch 18/70
# 3503/3503 [==============================] - 1s 326us/step - loss: 0.6843 - acc: 0.7048 - val_loss: 0.8897 - val_acc: 0.5744
# Epoch 19/70
# 3503/3503 [==============================] - 1s 327us/step - loss: 0.6679 - acc: 0.7168 - val_loss: 0.8832 - val_acc: 0.5718
# Epoch 20/70
# 3503/3503 [==============================] - 1s 335us/step - loss: 0.6544 - acc: 0.7211 - val_loss: 0.8776 - val_acc: 0.5923
# Epoch 21/70
# 3503/3503 [==============================] - 1s 329us/step - loss: 0.6253 - acc: 0.7397 - val_loss: 0.8803 - val_acc: 0.5821
# Epoch 22/70
# 3503/3503 [==============================] - 1s 335us/step - loss: 0.6305 - acc: 0.7334 - val_loss: 0.8686 - val_acc: 0.5846
# Epoch 23/70
# 3503/3503 [==============================] - 1s 336us/step - loss: 0.6097 - acc: 0.7514 - val_loss: 0.8676 - val_acc: 0.5872
# Epoch 24/70
# 3503/3503 [==============================] - 1s 330us/step - loss: 0.6004 - acc: 0.7485 - val_loss: 0.8672 - val_acc: 0.5897
# Epoch 25/70
# 3503/3503 [==============================] - 1s 334us/step - loss: 0.5900 - acc: 0.7471 - val_loss: 0.8738 - val_acc: 0.5846
# Epoch 26/70
# 3503/3503 [==============================] - 1s 333us/step - loss: 0.5743 - acc: 0.7636 - val_loss: 0.8776 - val_acc: 0.5923
# Epoch 27/70
# 3503/3503 [==============================] - 1s 321us/step - loss: 0.5471 - acc: 0.7693 - val_loss: 0.8639 - val_acc: 0.5872
# Epoch 28/70
# 3503/3503 [==============================] - 1s 338us/step - loss: 0.5365 - acc: 0.7839 - val_loss: 0.8747 - val_acc: 0.5846
# Epoch 29/70
# 3503/3503 [==============================] - 1s 333us/step - loss: 0.5383 - acc: 0.7802 - val_loss: 0.8751 - val_acc: 0.6000
# Epoch 30/70
# 3503/3503 [==============================] - 1s 320us/step - loss: 0.5322 - acc: 0.7805 - val_loss: 0.8696 - val_acc: 0.5949
# Epoch 31/70
# 3503/3503 [==============================] - 1s 326us/step - loss: 0.5106 - acc: 0.7959 - val_loss: 0.8849 - val_acc: 0.5974
# Epoch 32/70
# 3503/3503 [==============================] - 1s 337us/step - loss: 0.5070 - acc: 0.7959 - val_loss: 0.8710 - val_acc: 0.5897
# Epoch 33/70
# 3503/3503 [==============================] - 1s 324us/step - loss: 0.5019 - acc: 0.7993 - val_loss: 0.8744 - val_acc: 0.5897
# Epoch 34/70
# 3503/3503 [==============================] - 1s 326us/step - loss: 0.4856 - acc: 0.8059 - val_loss: 0.8771 - val_acc: 0.5949
# Epoch 35/70
# 3503/3503 [==============================] - 1s 321us/step - loss: 0.4665 - acc: 0.8233 - val_loss: 0.8852 - val_acc: 0.5974
# Epoch 36/70
# 3503/3503 [==============================] - 1s 329us/step - loss: 0.4632 - acc: 0.8082 - val_loss: 0.8906 - val_acc: 0.5949
# Epoch 37/70
# 3503/3503 [==============================] - 1s 338us/step - loss: 0.4622 - acc: 0.8182 - val_loss: 0.8834 - val_acc: 0.5897
# Epoch 38/70
# 3503/3503 [==============================] - 1s 332us/step - loss: 0.4463 - acc: 0.8219 - val_loss: 0.8819 - val_acc: 0.6000
# Epoch 39/70
# 3503/3503 [==============================] - 1s 325us/step - loss: 0.4440 - acc: 0.8193 - val_loss: 0.8938 - val_acc: 0.5872
# Epoch 40/70
# 3503/3503 [==============================] - 1s 339us/step - loss: 0.4328 - acc: 0.8261 - val_loss: 0.8931 - val_acc: 0.6000
# Epoch 41/70
# 3503/3503 [==============================] - 1s 332us/step - loss: 0.4391 - acc: 0.8210 - val_loss: 0.8911 - val_acc: 0.6103
# Epoch 42/70
# 3503/3503 [==============================] - 1s 327us/step - loss: 0.4131 - acc: 0.8361 - val_loss: 0.8966 - val_acc: 0.6000
# Epoch 43/70
# 3503/3503 [==============================] - 1s 356us/step - loss: 0.3912 - acc: 0.8407 - val_loss: 0.9048 - val_acc: 0.6026
# Epoch 44/70
# 3503/3503 [==============================] - 1s 321us/step - loss: 0.4069 - acc: 0.8410 - val_loss: 0.9073 - val_acc: 0.5974
# Epoch 45/70
# 3503/3503 [==============================] - 1s 319us/step - loss: 0.3993 - acc: 0.8390 - val_loss: 0.9105 - val_acc: 0.5923
# Epoch 46/70
# 3503/3503 [==============================] - 1s 328us/step - loss: 0.3746 - acc: 0.8544 - val_loss: 0.9130 - val_acc: 0.5974
# Epoch 47/70
# 3503/3503 [==============================] - 1s 323us/step - loss: 0.3846 - acc: 0.8487 - val_loss: 0.9226 - val_acc: 0.6103
# Epoch 48/70
# 3503/3503 [==============================] - 1s 334us/step - loss: 0.3640 - acc: 0.8593 - val_loss: 0.9290 - val_acc: 0.5974
# Epoch 49/70
# 3503/3503 [==============================] - 1s 332us/step - loss: 0.3733 - acc: 0.8610 - val_loss: 0.9287 - val_acc: 0.5949
# Epoch 50/70
# 3503/3503 [==============================] - 1s 325us/step - loss: 0.3655 - acc: 0.8558 - val_loss: 0.9303 - val_acc: 0.5923
# Epoch 51/70
# 3503/3503 [==============================] - 1s 337us/step - loss: 0.3487 - acc: 0.8655 - val_loss: 0.9410 - val_acc: 0.6000
# Epoch 52/70
# 3503/3503 [==============================] - 1s 343us/step - loss: 0.3524 - acc: 0.8615 - val_loss: 0.9283 - val_acc: 0.6051
# Epoch 53/70
# 3503/3503 [==============================] - 1s 335us/step - loss: 0.3368 - acc: 0.8687 - val_loss: 0.9328 - val_acc: 0.6051
# Epoch 54/70
# 3503/3503 [==============================] - 1s 351us/step - loss: 0.3387 - acc: 0.8747 - val_loss: 0.9511 - val_acc: 0.6026
# Epoch 55/70
# 3503/3503 [==============================] - 1s 343us/step - loss: 0.3371 - acc: 0.8744 - val_loss: 0.9415 - val_acc: 0.6051
# Epoch 56/70
# 3503/3503 [==============================] - 1s 333us/step - loss: 0.3181 - acc: 0.8741 - val_loss: 0.9585 - val_acc: 0.6077
# Epoch 57/70
# 3503/3503 [==============================] - 1s 343us/step - loss: 0.3225 - acc: 0.8752 - val_loss: 0.9634 - val_acc: 0.5974
# Epoch 58/70
# 3503/3503 [==============================] - 1s 337us/step - loss: 0.3164 - acc: 0.8752 - val_loss: 0.9671 - val_acc: 0.6000
# Epoch 59/70
# 3503/3503 [==============================] - 1s 343us/step - loss: 0.3282 - acc: 0.8772 - val_loss: 0.9650 - val_acc: 0.6000
# Epoch 60/70
# 3503/3503 [==============================] - 1s 336us/step - loss: 0.3113 - acc: 0.8810 - val_loss: 0.9704 - val_acc: 0.6051
# Epoch 61/70
# 3503/3503 [==============================] - 1s 334us/step - loss: 0.2989 - acc: 0.8867 - val_loss: 0.9720 - val_acc: 0.6000
# Epoch 62/70
# 3503/3503 [==============================] - 1s 331us/step - loss: 0.2987 - acc: 0.8884 - val_loss: 0.9763 - val_acc: 0.6026
# Epoch 63/70
# 3503/3503 [==============================] - 1s 327us/step - loss: 0.2950 - acc: 0.8921 - val_loss: 0.9851 - val_acc: 0.5923
# Epoch 64/70
# 3503/3503 [==============================] - 1s 334us/step - loss: 0.2871 - acc: 0.8878 - val_loss: 0.9989 - val_acc: 0.6000
# Epoch 65/70
# 3503/3503 [==============================] - 1s 331us/step - loss: 0.2743 - acc: 0.8924 - val_loss: 1.0005 - val_acc: 0.5949
# Epoch 66/70
# 3503/3503 [==============================] - 1s 345us/step - loss: 0.2735 - acc: 0.8995 - val_loss: 1.0035 - val_acc: 0.6077
# Epoch 67/70
# 3503/3503 [==============================] - 1s 336us/step - loss: 0.2710 - acc: 0.8952 - val_loss: 1.0161 - val_acc: 0.5949
# Epoch 68/70
# 3503/3503 [==============================] - 1s 339us/step - loss: 0.2617 - acc: 0.8981 - val_loss: 1.0130 - val_acc: 0.6051
# Epoch 69/70
# 3503/3503 [==============================] - 1s 333us/step - loss: 0.2752 - acc: 0.8984 - val_loss: 1.0152 - val_acc: 0.6077
# Epoch 70/70
# 3503/3503 [==============================] - 1s 341us/step - loss: 0.2701 - acc: 0.9035 - val_loss: 1.0172 - val_acc: 0.6026

# %%
model.evaluate(X_test.toarray(), yt, batch_size=32)
# Out:
# 4573/4573 [==============================] - 1s 175us/step
# [1.0540357939450922, 0.61469494857231277]

# %%
del model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-a7ab210f85a1> in <module>()
# ----> 1 del model
#
# NameError: name 'model' is not defined
